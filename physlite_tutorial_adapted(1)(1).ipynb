# %% [markdown]
# # How to use a PHYSLITE file

# %% [markdown]
# For the ATLAS Open Data for Research, we have released hundreds of datasets in PHYSLITE format. In this notebook we are going to show you how to access the event and variables, and how to do a basic analysis using `uproot` and `awkward` arrays.

# %%
# Import basic libraries
import copy # copy variables
import os   # manage paths

import uproot   # use of root files
import awkward as ak    # nested, variable sized data
import vector   # lorentz vectors
vector.register_awkward()
import matplotlib.pyplot as plt # plotting
import tqdm # progress bars
import atlasopenmagic as atom # ATLAS Open Data package
import requests

# %% [markdown]
# In this notebook we are using a dataset from `mc20_13TeV.410470.PhPy8EG_A14_ttbar_hdamp258p75_nonallhad.deriv.DAOD_PHYSLITE.e6337_s3681_r13167_p5855`. We are going to retrieve a subset of this notebook using `atlasopenmagic` package. The package is set by default to the proton-proton data for research.

# %%
atom.get_current_release()
# Out:
# '2024r-pp'

# %% [markdown]
# with `get_urls` we can get the list of URLs for all the subsets that conform `mc20_13TeV.410470.PhPy8EG_A14_ttbar_hdamp258p75_nonallhad.deriv.DAOD_PHYSLITE.e6337_s3681_r13167_p5855`. With protocol you can select if you prefer streaming via the xrootd protocol (protocol='root'), or https. For mybinder we will run using https, but it should be faster with xrootd.

# %%
urls_sample = atom.get_urls(410470, protocol='https')
urls_sample[:5]
# Out:
# Fetching and caching all metadata for release: 2024r-pp...
# Successfully cached 374 datasets.
# ['https://opendata.cern.ch/eos/opendata/atlas/rucio/mc20_13TeV/DAOD_PHYSLITE.37620644._000012.pool.root.1',
#  'https://opendata.cern.ch/eos/opendata/atlas/rucio/mc20_13TeV/DAOD_PHYSLITE.37620644._000013.pool.root.1',
#  'https://opendata.cern.ch/eos/opendata/atlas/rucio/mc20_13TeV/DAOD_PHYSLITE.37620644._000014.pool.root.1',
#  'https://opendata.cern.ch/eos/opendata/atlas/rucio/mc20_13TeV/DAOD_PHYSLITE.37620644._000015.pool.root.1',
#  'https://opendata.cern.ch/eos/opendata/atlas/rucio/mc20_13TeV/DAOD_PHYSLITE.37620644._000017.pool.root.1']

# %% [markdown]
# For simplicity, we are going to select the first one.

# %%
# mc20_13TeV.410470.PhPy8EG_A14_ttbar_hdamp258p75_nonallhad.deriv.DAOD_PHYSLITE.e6337_s3681_r13167_p5855
filename = urls_sample[0]
filename
# Out:
# 'https://opendata.cern.ch/eos/opendata/atlas/rucio/mc20_13TeV/DAOD_PHYSLITE.37620644._000012.pool.root.1'

# %%
# Download the file, use a local copy
local_filename = filename.split("/")[-1]
print(f"Downloading {filename} to {local_filename} ...")
with requests.get(filename, stream=True) as r:
    r.raise_for_status()
    with open(local_filename, "wb") as f:
        for chunk in r.iter_content(chunk_size=8192):
            f.write(chunk)
print('download complete')
# Out:
# Downloading https://opendata.cern.ch/eos/opendata/atlas/rucio/mc20_13TeV/DAOD_PHYSLITE.37620644._000012.pool.root.1 to DAOD_PHYSLITE.37620644._000012.pool.root.1 ...
# download complete

# %% [markdown]
# ## Read PHYSLITE with uproot
# We can open a `TFile` using [`uproot.open`](https://uproot.readthedocs.io/en/latest/uproot.reading.open.html). To check the Ttree objects in the file we use the `.keys()` method.

# %%
print('TTree objects inside the ROOT file:')
for ii in uproot.open(local_filename).keys():
    print('-',ii)
# Out:
# TTree objects inside the ROOT file:
# - ##Params;3
# - ##Params;2
# - ##Shapes;3
# - ##Shapes;2
# - ##Links;3
# - ##Links;2
# - MetaData;1
# - MetaDataHdr;1
# - MetaDataHdrForm;1
# - CollectionTree;1
# - POOLContainer;1
# - POOLContainerForm;1
# - POOLCollectionTree;1

# %% [markdown]
# To get directly a `TTree`, pass a dictionary with `{filename: treename}`. `CollectionTree` is the TTree with the events information.

# %%
tree = uproot.open({local_filename: "CollectionTree"})

# %% [markdown]
# ### List branches
# Most of the data in a PHYSLITE is in the branches with "AuxDyn" in their name. This branches are type `vector<int>` or `vector<float>`, i.e. a vector of integers or floats. We can see all the branches with the `.show()` method. Here, we are only showing the first 10:

# %%
# Display only the first 10 branches
first_10_branches = list(tree.keys())[:10]
tree.show(filter_name=first_10_branches, name_width=50, typename_width=50, interpretation_width=50)
# Out:
# name                                               | typename                                           | interpretation
# ---------------------------------------------------+----------------------------------------------------+---------------------------------------------------
# xTrigDecisionAux.                                  | xAOD::TrigDecisionAuxInfo_v1                       | AsGroup(<TBranchElement 'xTrigDecisionAux.' (20...
# xTrigDecisionAux./xTrigDecisionAux.xAOD::AuxInf... | unknown                                            | <UnknownInterpretation 'none of the rules match...
# xTrigDecisionAux./xTrigDecisionAux.smk             | uint32_t                                           | AsDtype('>u4')
# xTrigDecisionAux./xTrigDecisionAux.bgCode          | int8_t                                             | AsDtype('int8')
# xTrigDecisionAux./xTrigDecisionAux.tav             | std::vector<uint32_t>                              | AsJagged(AsDtype('>u4'), header_bytes=10)
# xTrigDecisionAux./xTrigDecisionAux.tap             | std::vector<uint32_t>                              | AsJagged(AsDtype('>u4'), header_bytes=10)
# xTrigDecisionAux./xTrigDecisionAux.tbp             | std::vector<uint32_t>                              | AsJagged(AsDtype('>u4'), header_bytes=10)
# xTrigDecisionAux./xTrigDecisionAux.lvl2ErrorBits   | uint32_t                                           | AsDtype('>u4')
# xTrigDecisionAux./xTrigDecisionAux.efErrorBits     | uint32_t                                           | AsDtype('>u4')
# xTrigDecisionAux./xTrigDecisionAux.lvl2Truncated   | bool                                               | AsDtype('bool')

# %%
for branch in tree.keys():
    print(branch)
# Out:
# xTrigDecisionAux.
# xTrigDecisionAux./xTrigDecisionAux.xAOD::AuxInfoBase
# xTrigDecisionAux./xTrigDecisionAux.smk
# xTrigDecisionAux./xTrigDecisionAux.bgCode
# xTrigDecisionAux./xTrigDecisionAux.tav
# xTrigDecisionAux./xTrigDecisionAux.tap
# xTrigDecisionAux./xTrigDecisionAux.tbp
# xTrigDecisionAux./xTrigDecisionAux.lvl2ErrorBits
# xTrigDecisionAux./xTrigDecisionAux.efErrorBits
# xTrigDecisionAux./xTrigDecisionAux.lvl2Truncated
# xTrigDecisionAux./xTrigDecisionAux.efTruncated
# xTrigDecisionAux./xTrigDecisionAux.lvl2PassedPhysics
# xTrigDecisionAux./xTrigDecisionAux.efPassedPhysics
# xTrigDecisionAux./xTrigDecisionAux.lvl2PassedRaw
# xTrigDecisionAux./xTrigDecisionAux.efPassedRaw
# xTrigDecisionAux./xTrigDecisionAux.lvl2PassedThrough
# xTrigDecisionAux./xTrigDecisionAux.efPassedThrough
# xTrigDecisionAux./xTrigDecisionAux.lvl2Prescaled
# xTrigDecisionAux./xTrigDecisionAux.efPrescaled
# xTrigDecisionAux./xTrigDecisionAux.lvl2Resurrected
# xTrigDecisionAux./xTrigDecisionAux.efResurrected
# METAssoc_AnalysisMETAux.
# METAssoc_AnalysisMETAux./METAssoc_AnalysisMETAux.xAOD::AuxContainerBase
# METAssoc_AnalysisMETAux./METAssoc_AnalysisMETAux.jetLink
# METAssoc_AnalysisMETAux./METAssoc_AnalysisMETAux.objectLinks
# METAssoc_AnalysisMETAux./METAssoc_AnalysisMETAux.calpx
# METAssoc_AnalysisMETAux./METAssoc_AnalysisMETAux.calpy
# METAssoc_AnalysisMETAux./METAssoc_AnalysisMETAux.calpz
# METAssoc_AnalysisMETAux./METAssoc_AnalysisMETAux.cale
# METAssoc_AnalysisMETAux./METAssoc_AnalysisMETAux.calsumpt
# METAssoc_AnalysisMETAux./METAssoc_AnalysisMETAux.calkey
# METAssoc_AnalysisMETAux./METAssoc_AnalysisMETAux.trkpx
# METAssoc_AnalysisMETAux./METAssoc_AnalysisMETAux.trkpy
# METAssoc_AnalysisMETAux./METAssoc_AnalysisMETAux.trkpz
# METAssoc_AnalysisMETAux./METAssoc_AnalysisMETAux.trke
# METAssoc_AnalysisMETAux./METAssoc_AnalysisMETAux.trksumpt
# METAssoc_AnalysisMETAux./METAssoc_AnalysisMETAux.trkkey
# METAssoc_AnalysisMETAux./METAssoc_AnalysisMETAux.jettrkpx
# METAssoc_AnalysisMETAux./METAssoc_AnalysisMETAux.jettrkpy
# METAssoc_AnalysisMETAux./METAssoc_AnalysisMETAux.jettrkpz
# METAssoc_AnalysisMETAux./METAssoc_AnalysisMETAux.jettrke
# METAssoc_AnalysisMETAux./METAssoc_AnalysisMETAux.jettrksumpt
# METAssoc_AnalysisMETAux./METAssoc_AnalysisMETAux.overlapIndices
# METAssoc_AnalysisMETAux./METAssoc_AnalysisMETAux.overlapTypes
# METAssoc_AnalysisMETAux./METAssoc_AnalysisMETAux.isMisc
# EventInfoAux.
# Kt4EMPFlowEventShapeAux.
# AnalysisElectronsAux.
# AnalysisJetsAux.
# AnalysisLargeRJetsAux.
# AnalysisMuonsAux.
# AnalysisPhotonsAux.
# AnalysisSiHitElectronsAux.
# AnalysisTauJetsAux.
# AnalysisTrigMatch_HLT_2e12_lhloose_L12EM10VHAux.
# AnalysisTrigMatch_HLT_2e12_lhloose_mu10Aux.
# AnalysisTrigMatch_HLT_2e12_lhloose_nod0_mu10Aux.
# AnalysisTrigMatch_HLT_2e12_lhloose_nodeta_L12EM10VHAux.
# AnalysisTrigMatch_HLT_2e12_lhloose_nodphires_L12EM10VHAux.
# AnalysisTrigMatch_HLT_2e12_lhvloose_L12EM10VHAux.
# AnalysisTrigMatch_HLT_2e12_lhvloose_nod0_L12EM10VHAux.
# AnalysisTrigMatch_HLT_2e15_lhvloose_L12EM13VHAux.
# AnalysisTrigMatch_HLT_2e15_lhvloose_nod0_L12EM13VHAux.
# AnalysisTrigMatch_HLT_2e17_lhvlooseAux.
# AnalysisTrigMatch_HLT_2e17_lhvloose_nod0Aux.
# AnalysisTrigMatch_HLT_2e17_lhvloose_nod0_ringerAux.
# AnalysisTrigMatch_HLT_2g20_loose_g15_looseAux.
# AnalysisTrigMatch_HLT_2g20_tightAux.
# AnalysisTrigMatch_HLT_2g22_tightAux.
# AnalysisTrigMatch_HLT_2g22_tight_L1EM7_EMPTYAux.
# AnalysisTrigMatch_HLT_2g22_tight_L1EM7_UNPAIRED_ISOAux.
# AnalysisTrigMatch_HLT_2g50_loose_L12EM20VHAux.
# AnalysisTrigMatch_HLT_2mu10Aux.
# AnalysisTrigMatch_HLT_2mu10_nomucombAux.
# AnalysisTrigMatch_HLT_2mu14Aux.
# AnalysisTrigMatch_HLT_2mu14_nomucombAux.
# AnalysisTrigMatch_HLT_2mu20_L12MU20_OVERLAYAux.
# AnalysisTrigMatch_HLT_2mu4_bJpsimumuAux.
# AnalysisTrigMatch_HLT_2mu4_bUpsimumuAux.
# AnalysisTrigMatch_HLT_2mu6_10invm30_pt2_z10Aux.
# AnalysisTrigMatch_HLT_2mu6_bJpsimumuAux.
# AnalysisTrigMatch_HLT_2mu6_bJpsimumu_delayedAux.
# AnalysisTrigMatch_HLT_2mu6_bUpsimumuAux.
# AnalysisTrigMatch_HLT_2mu6_bUpsimumu_delayedAux.
# AnalysisTrigMatch_HLT_3g15_looseAux.
# AnalysisTrigMatch_HLT_3g20_looseAux.
# AnalysisTrigMatch_HLT_3mu4Aux.
# AnalysisTrigMatch_HLT_3mu4_nomucombAux.
# AnalysisTrigMatch_HLT_3mu6Aux.
# AnalysisTrigMatch_HLT_3mu6_msonlyAux.
# AnalysisTrigMatch_HLT_3mu6_msonly_L1MU4_UNPAIRED_ISOAux.
# AnalysisTrigMatch_HLT_3mu6_msonly_L1MU6_EMPTYAux.
# AnalysisTrigMatch_HLT_e100_lhvloose_nod0Aux.
# AnalysisTrigMatch_HLT_e10_lhvloose_L1EM7Aux.
# AnalysisTrigMatch_HLT_e10_lhvloose_nod0_L1EM7Aux.
# AnalysisTrigMatch_HLT_e120_lhlooseAux.
# AnalysisTrigMatch_HLT_e120_lhloose_nod0Aux.
# AnalysisTrigMatch_HLT_e120_lhvloose_nod0Aux.
# AnalysisTrigMatch_HLT_e12_lhloose_2mu10Aux.
# AnalysisTrigMatch_HLT_e12_lhloose_nod0_2mu10Aux.
# AnalysisTrigMatch_HLT_e12_lhvloose_L1EM10VHAux.
# AnalysisTrigMatch_HLT_e12_lhvloose_nod0_L1EM10VHAux.
# AnalysisTrigMatch_HLT_e140_lhloose_nod0Aux.
# AnalysisTrigMatch_HLT_e140_lhloose_nod0_ringerAux.
# AnalysisTrigMatch_HLT_e140_lhvloose_nod0Aux.
# AnalysisTrigMatch_HLT_e15_lhvloose_L1EM13VHAux.
# AnalysisTrigMatch_HLT_e15_lhvloose_nod0_L1EM7Aux.
# AnalysisTrigMatch_HLT_e17_lhloose_2e9_lhlooseAux.
# AnalysisTrigMatch_HLT_e17_lhloose_mu14Aux.
# AnalysisTrigMatch_HLT_e17_lhloose_nod0_2e12_lhloose_nod0_L1EM15VH_3EM10VHAux.
# AnalysisTrigMatch_HLT_e17_lhloose_nod0_2e9_lhloose_nod0Aux.
# AnalysisTrigMatch_HLT_e17_lhloose_nod0_mu14Aux.
# AnalysisTrigMatch_HLT_e17_lhmedium_iloose_2e9_lhmediumAux.
# AnalysisTrigMatch_HLT_e17_lhmedium_iloose_tau25_medium1_tracktwoAux.
# AnalysisTrigMatch_HLT_e17_lhmedium_nod0_iloose_2e9_lhmedium_nod0Aux.
# AnalysisTrigMatch_HLT_e17_lhmedium_nod0_iloose_tau25_medium1_tracktwoAux.
# AnalysisTrigMatch_HLT_e17_lhmedium_nod0_ivarloose_tau25_medium1_tracktwoAux.
# AnalysisTrigMatch_HLT_e17_lhmedium_nod0_ivarloose_tau25_medium1_tracktwo_L1DR-EM15TAU12I-J25Aux.
# AnalysisTrigMatch_HLT_e17_lhmedium_nod0_tau25_medium1_tracktwoAux.
# AnalysisTrigMatch_HLT_e17_lhmedium_nod0_tau80_medium1_tracktwoAux.
# AnalysisTrigMatch_HLT_e17_lhmedium_tau25_medium1_tracktwoAux.
# AnalysisTrigMatch_HLT_e17_lhmedium_tau80_medium1_tracktwoAux.
# AnalysisTrigMatch_HLT_e17_lhvlooseAux.
# AnalysisTrigMatch_HLT_e17_lhvloose_nod0Aux.
# AnalysisTrigMatch_HLT_e200_etcutAux.
# AnalysisTrigMatch_HLT_e20_lhvlooseAux.
# AnalysisTrigMatch_HLT_e20_lhvloose_nod0Aux.
# AnalysisTrigMatch_HLT_e22_lhvloose_nod0_e12_lhvloose_nod0_e10_lhvloose_nod0_L1EM20VH_2EM10VH_3EM8VHAux.
# AnalysisTrigMatch_HLT_e24_lhmedium_L1EM20VHAux.
# AnalysisTrigMatch_HLT_e24_lhmedium_L1EM20VHI_mu8noL1Aux.
# AnalysisTrigMatch_HLT_e24_lhmedium_iloose_L1EM20VHAux.
# AnalysisTrigMatch_HLT_e24_lhmedium_nod0_L1EM20VHI_mu8noL1Aux.
# AnalysisTrigMatch_HLT_e24_lhmedium_nod0_iloose_L1EM20VHAux.
# AnalysisTrigMatch_HLT_e24_lhmedium_nod0_ivarloose_tau35_medium1_tracktwoAux.
# AnalysisTrigMatch_HLT_e24_lhtight_nod0_ivarlooseAux.
# AnalysisTrigMatch_HLT_e24_lhvloose_nod0_L1EM18VHAux.
# AnalysisTrigMatch_HLT_e26_lhmedium_L1EM22VHI_mu8noL1Aux.
# AnalysisTrigMatch_HLT_e26_lhmedium_nod0_L1EM22VHI_mu8noL1Aux.
# AnalysisTrigMatch_HLT_e26_lhtight_cutd0dphideta_ivarlooseAux.
# AnalysisTrigMatch_HLT_e26_lhtight_ivarlooseAux.
# AnalysisTrigMatch_HLT_e26_lhtight_nod0Aux.
# AnalysisTrigMatch_HLT_e26_lhtight_nod0_e15_etcut_L1EM7_ZeeAux.
# AnalysisTrigMatch_HLT_e26_lhtight_nod0_ivarlooseAux.
# AnalysisTrigMatch_HLT_e26_lhtight_nod0_ringer_ivarlooseAux.
# AnalysisTrigMatch_HLT_e26_lhtight_smooth_ivarlooseAux.
# AnalysisTrigMatch_HLT_e26_lhvloose_nod0_L1EM20VHAux.
# AnalysisTrigMatch_HLT_e28_lhtight_nod0_L1EM22VHIAux.
# AnalysisTrigMatch_HLT_e28_lhtight_nod0_ringer_ivarlooseAux.
# AnalysisTrigMatch_HLT_e28_lhvloose_nod0_L1EM20VHAux.
# AnalysisTrigMatch_HLT_e300_etcutAux.
# AnalysisTrigMatch_HLT_e5_lhvlooseAux.
# AnalysisTrigMatch_HLT_e5_lhvloose_nod0Aux.
# AnalysisTrigMatch_HLT_e60_lhmediumAux.
# AnalysisTrigMatch_HLT_e60_lhmedium_L1EM24VHIAux.
# AnalysisTrigMatch_HLT_e60_lhmedium_nod0Aux.
# AnalysisTrigMatch_HLT_e60_lhmedium_nod0_ringerAux.
# AnalysisTrigMatch_HLT_e60_lhvloose_nod0Aux.
# AnalysisTrigMatch_HLT_e60_mediumAux.
# AnalysisTrigMatch_HLT_e70_lhvloose_nod0Aux.
# AnalysisTrigMatch_HLT_e7_lhmedium_mu24Aux.
# AnalysisTrigMatch_HLT_e7_lhmedium_nod0_mu24Aux.
# AnalysisTrigMatch_HLT_e80_lhvloose_nod0Aux.
# AnalysisTrigMatch_HLT_g120_looseAux.
# AnalysisTrigMatch_HLT_g140_looseAux.
# AnalysisTrigMatch_HLT_g200_etcutAux.
# AnalysisTrigMatch_HLT_g300_etcutAux.
# AnalysisTrigMatch_HLT_g35_loose_g25_looseAux.
# AnalysisTrigMatch_HLT_g35_loose_g25_loose_L12EM20VHAux.
# AnalysisTrigMatch_HLT_g35_medium_g25_medium_L12EM20VHAux.
# AnalysisTrigMatch_HLT_g35_medium_g25_medium_L1EM7_EMPTYAux.
# AnalysisTrigMatch_HLT_g35_medium_g25_medium_L1EM7_UNPAIRED_ISOAux.
# AnalysisTrigMatch_HLT_id_cosmicid_L1MU11_EMPTYAux.
# AnalysisTrigMatch_HLT_mu10Aux.
# AnalysisTrigMatch_HLT_mu10_bJpsi_TrklooseAux.
# AnalysisTrigMatch_HLT_mu11_2mu4noL1_nscan03_L1MU11_2MU6Aux.
# AnalysisTrigMatch_HLT_mu11_L1MU10_2mu4noL1_nscan03_L1MU10_2MU6Aux.
# AnalysisTrigMatch_HLT_mu11_nomucomb_2mu4noL1_nscan03_L1MU11_2MU6Aux.
# AnalysisTrigMatch_HLT_mu11_nomucomb_2mu4noL1_nscan03_L1MU11_2MU6_bTauAux.
# AnalysisTrigMatch_HLT_mu11_nomucomb_mu6noL1_nscan03_L1MU11_2MU6_bTauAux.
# AnalysisTrigMatch_HLT_mu11_nomucomb_mu6noL1_nscan03_L1MU11_2MU6_bTau_delayedAux.
# AnalysisTrigMatch_HLT_mu13_mu13_idperf_ZmumuAux.
# AnalysisTrigMatch_HLT_mu14Aux.
# AnalysisTrigMatch_HLT_mu14_iloose_tau25_medium1_tracktwoAux.
# AnalysisTrigMatch_HLT_mu14_iloose_tau35_medium1_tracktwoAux.
# AnalysisTrigMatch_HLT_mu14_ivarloose_L1MU11_tau35_medium1_tracktwo_L1MU11_TAU20IMAux.
# AnalysisTrigMatch_HLT_mu14_ivarloose_tau25_medium1_tracktwoAux.
# AnalysisTrigMatch_HLT_mu14_ivarloose_tau25_medium1_tracktwo_L1DR-MU10TAU12I_TAU12I-J25Aux.
# AnalysisTrigMatch_HLT_mu14_ivarloose_tau35_medium1_tracktwoAux.
# AnalysisTrigMatch_HLT_mu14_tau25_medium1_tracktwoAux.
# AnalysisTrigMatch_HLT_mu14_tau35_medium1_tracktwoAux.
# AnalysisTrigMatch_HLT_mu18Aux.
# AnalysisTrigMatch_HLT_mu18_2mu0noL1_JpsimumuFSAux.
# AnalysisTrigMatch_HLT_mu18_2mu4_JpsimumuL2Aux.
# AnalysisTrigMatch_HLT_mu18_2mu4noL1Aux.
# AnalysisTrigMatch_HLT_mu18_mu8noL1Aux.
# AnalysisTrigMatch_HLT_mu20Aux.
# AnalysisTrigMatch_HLT_mu20_2mu0noL1_JpsimumuFSAux.
# AnalysisTrigMatch_HLT_mu20_2mu4_JpsimumuL2Aux.
# AnalysisTrigMatch_HLT_mu20_2mu4noL1Aux.
# AnalysisTrigMatch_HLT_mu20_iloose_L1MU15Aux.
# AnalysisTrigMatch_HLT_mu20_ivarmedium_mu8noL1Aux.
# AnalysisTrigMatch_HLT_mu20_l2idonly_mu6noL1_nscan03Aux.
# AnalysisTrigMatch_HLT_mu20_msonly_mu10noL1_msonly_nscan05_noCombAux.
# AnalysisTrigMatch_HLT_mu20_msonly_mu10noL1_msonly_nscan05_noComb_L1MU4_UNPAIRED_ISOAux.
# AnalysisTrigMatch_HLT_mu20_msonly_mu10noL1_msonly_nscan05_noComb_L1MU6_EMPTYAux.
# AnalysisTrigMatch_HLT_mu20_msonly_mu15noL1_msonly_nscan05_noCombAux.
# AnalysisTrigMatch_HLT_mu20_msonly_mu15noL1_msonly_nscan05_noComb_L1MU4_UNPAIRED_ISOAux.
# AnalysisTrigMatch_HLT_mu20_msonly_mu15noL1_msonly_nscan05_noComb_L1MU6_EMPTYAux.
# AnalysisTrigMatch_HLT_mu20_msonly_mu6noL1_msonly_nscan05Aux.
# AnalysisTrigMatch_HLT_mu20_mu8noL1Aux.
# AnalysisTrigMatch_HLT_mu20_nomucomb_mu6noL1_nscan03Aux.
# AnalysisTrigMatch_HLT_mu22Aux.
# AnalysisTrigMatch_HLT_mu22_mu8noL1Aux.
# AnalysisTrigMatch_HLT_mu22_mu8noL1_calotag_0eta010Aux.
# AnalysisTrigMatch_HLT_mu24Aux.
# AnalysisTrigMatch_HLT_mu24_ilooseAux.
# AnalysisTrigMatch_HLT_mu24_imediumAux.
# AnalysisTrigMatch_HLT_mu24_ivarlooseAux.
# AnalysisTrigMatch_HLT_mu24_ivarmediumAux.
# AnalysisTrigMatch_HLT_mu26_ivarmediumAux.
# AnalysisTrigMatch_HLT_mu40Aux.
# AnalysisTrigMatch_HLT_mu4Aux.
# AnalysisTrigMatch_HLT_mu4_bJpsi_TrklooseAux.
# AnalysisTrigMatch_HLT_mu4_j15_bperf_split_dr05_dz02Aux.
# AnalysisTrigMatch_HLT_mu4_j15_dr05Aux.
# AnalysisTrigMatch_HLT_mu4_j25_bperf_split_dr05_dz02Aux.
# AnalysisTrigMatch_HLT_mu4_j25_dr05Aux.
# AnalysisTrigMatch_HLT_mu4_j35_bperf_split_dr05_dz02Aux.
# AnalysisTrigMatch_HLT_mu4_j35_dr05Aux.
# AnalysisTrigMatch_HLT_mu4_j55_bperf_split_dr05_dz02Aux.
# AnalysisTrigMatch_HLT_mu4_j55_dr05Aux.
# AnalysisTrigMatch_HLT_mu4_mu4_idperf_bJpsimumu_noidAux.
# AnalysisTrigMatch_HLT_mu50Aux.
# AnalysisTrigMatch_HLT_mu60_0eta105_msonlyAux.
# AnalysisTrigMatch_HLT_mu6Aux.
# AnalysisTrigMatch_HLT_mu6_2mu4Aux.
# AnalysisTrigMatch_HLT_mu6_bJpsi_TrklooseAux.
# AnalysisTrigMatch_HLT_mu6_idperfAux.
# AnalysisTrigMatch_HLT_mu6_iloose_mu6_11invm24_noosAux.
# AnalysisTrigMatch_HLT_mu6_j110_bperf_split_dr05_dz02Aux.
# AnalysisTrigMatch_HLT_mu6_j110_dr05Aux.
# AnalysisTrigMatch_HLT_mu6_j150_bperf_split_dr05_dz02Aux.
# AnalysisTrigMatch_HLT_mu6_j150_dr05Aux.
# AnalysisTrigMatch_HLT_mu6_j175_bperf_split_dr05_dz02Aux.
# AnalysisTrigMatch_HLT_mu6_j175_dr05Aux.
# AnalysisTrigMatch_HLT_mu6_j85_bperf_split_dr05_dz02Aux.
# AnalysisTrigMatch_HLT_mu6_j85_dr05Aux.
# AnalysisTrigMatch_HLT_mu6_mu4_bJpsimumuAux.
# AnalysisTrigMatch_HLT_mu6_mu4_bJpsimumu_delayedAux.
# AnalysisTrigMatch_HLT_mu6_mu4_bUpsimumuAux.
# AnalysisTrigMatch_HLT_mu6_mu4_bUpsimumu_delayedAux.
# AnalysisTrigMatch_HLT_mu6_nomucomb_2mu4_nomucomb_L1MU6_3MU4Aux.
# AnalysisTrigMatch_HLT_mu6_nomucomb_2mu4_nomucomb_delayed_L1MU6_3MU4Aux.
# BTagging_AntiKt4EMPFlowAux.
# BTagging_AntiKtVR30Rmax4Rmin02TrackAux.
# BornLeptonsAux.
# CombinedMuonTrackParticlesAux.
# ExtrapolatedMuonTrackParticlesAux.
# FourLeptonVerticesAux.
# GSFConversionVerticesAux.
# GSFTrackParticlesAux.
# HardScatterParticlesAux.
# HardScatterVerticesAux.
# InDetTrackParticlesAux.
# MET_Core_AnalysisMETAux.
# MET_TruthAux.
# MuonSpectrometerTrackParticlesAux.
# PrimaryVerticesAux.
# TauTracksAux.
# TruthBSMAux.
# TruthBSMWithDecayParticlesAux.
# TruthBSMWithDecayVerticesAux.
# TruthBosonAux.
# TruthBosonsWithDecayParticlesAux.
# TruthBosonsWithDecayVerticesAux.
# TruthBottomAux.
# TruthElectronsAux.
# TruthEventsAux.
# TruthForwardProtonsAux.
# TruthMuonsAux.
# TruthNeutrinosAux.
# TruthPhotonsAux.
# TruthPrimaryVerticesAux.
# TruthTausAux.
# TruthTopAux.
# egammaClustersAux.
# AntiKt10TruthSoftDropBeta100Zcut10JetsAux.
# AntiKt10TruthSoftDropBeta100Zcut10JetsAux./AntiKt10TruthSoftDropBeta100Zcut10JetsAux.xAOD::AuxContainerBase
# AntiKt10TruthSoftDropBeta100Zcut10JetsAux./AntiKt10TruthSoftDropBeta100Zcut10JetsAux.pt
# AntiKt10TruthSoftDropBeta100Zcut10JetsAux./AntiKt10TruthSoftDropBeta100Zcut10JetsAux.eta
# AntiKt10TruthSoftDropBeta100Zcut10JetsAux./AntiKt10TruthSoftDropBeta100Zcut10JetsAux.phi
# AntiKt10TruthSoftDropBeta100Zcut10JetsAux./AntiKt10TruthSoftDropBeta100Zcut10JetsAux.m
# AntiKt10TruthSoftDropBeta100Zcut10JetsAux./AntiKt10TruthSoftDropBeta100Zcut10JetsAux.constituentLinks
# AntiKt10TruthSoftDropBeta100Zcut10JetsAux./AntiKt10TruthSoftDropBeta100Zcut10JetsAux.constituentWeights
# AntiKt10UFOCSSKJetsAux.
# AntiKt10UFOCSSKJetsAux./AntiKt10UFOCSSKJetsAux.xAOD::AuxContainerBase
# AntiKt10UFOCSSKJetsAux./AntiKt10UFOCSSKJetsAux.pt
# AntiKt10UFOCSSKJetsAux./AntiKt10UFOCSSKJetsAux.eta
# AntiKt10UFOCSSKJetsAux./AntiKt10UFOCSSKJetsAux.phi
# AntiKt10UFOCSSKJetsAux./AntiKt10UFOCSSKJetsAux.m
# AntiKt10UFOCSSKJetsAux./AntiKt10UFOCSSKJetsAux.constituentLinks
# AntiKt10UFOCSSKJetsAux./AntiKt10UFOCSSKJetsAux.constituentWeights
# AntiKt4TruthDressedWZJetsAux.
# AntiKt4TruthDressedWZJetsAux./AntiKt4TruthDressedWZJetsAux.xAOD::AuxContainerBase
# AntiKt4TruthDressedWZJetsAux./AntiKt4TruthDressedWZJetsAux.pt
# AntiKt4TruthDressedWZJetsAux./AntiKt4TruthDressedWZJetsAux.eta
# AntiKt4TruthDressedWZJetsAux./AntiKt4TruthDressedWZJetsAux.phi
# AntiKt4TruthDressedWZJetsAux./AntiKt4TruthDressedWZJetsAux.m
# AntiKt4TruthDressedWZJetsAux./AntiKt4TruthDressedWZJetsAux.constituentLinks
# AntiKt4TruthDressedWZJetsAux./AntiKt4TruthDressedWZJetsAux.constituentWeights
# TrigConfKeys
# EventInfo
# xTrigDecision
# METAssoc_AnalysisMET
# Kt4EMPFlowEventShape
# AnalysisElectrons
# AnalysisSiHitElectrons
# FourLeptonVertices
# GSFConversionVertices
# PrimaryVertices
# MET_Core_AnalysisMET
# MET_Truth
# AnalysisPhotons
# AnalysisTauJets
# AnalysisMuons
# TruthEvents
# egammaClusters
# BornLeptons
# HardScatterParticles
# TruthBSM
# TruthBSMWithDecayParticles
# TruthBoson
# TruthBosonsWithDecayParticles
# TruthBottom
# TruthElectrons
# TruthForwardProtons
# TruthMuons
# TruthNeutrinos
# TruthPhotons
# TruthTaus
# TruthTop
# HardScatterVertices
# TruthBSMWithDecayVertices
# TruthBosonsWithDecayVertices
# TruthPrimaryVertices
# AnalysisJets
# AnalysisLargeRJets
# AntiKt10TruthSoftDropBeta100Zcut10Jets
# AntiKt10UFOCSSKJets
# AntiKt4TruthDressedWZJets
# BTagging_AntiKt4EMPFlow
# BTagging_AntiKtVR30Rmax4Rmin02Track
# CombinedMuonTrackParticles
# ExtrapolatedMuonTrackParticles
# GSFTrackParticles
# InDetTrackParticles
# MuonSpectrometerTrackParticles
# TauTracks
# AnalysisTrigMatch_HLT_2e12_lhloose_L12EM10VH
# AnalysisTrigMatch_HLT_2e12_lhloose_mu10
# AnalysisTrigMatch_HLT_2e12_lhloose_nod0_mu10
# AnalysisTrigMatch_HLT_2e12_lhloose_nodeta_L12EM10VH
# AnalysisTrigMatch_HLT_2e12_lhloose_nodphires_L12EM10VH
# AnalysisTrigMatch_HLT_2e12_lhvloose_L12EM10VH
# AnalysisTrigMatch_HLT_2e12_lhvloose_nod0_L12EM10VH
# AnalysisTrigMatch_HLT_2e15_lhvloose_L12EM13VH
# AnalysisTrigMatch_HLT_2e15_lhvloose_nod0_L12EM13VH
# AnalysisTrigMatch_HLT_2e17_lhvloose
# AnalysisTrigMatch_HLT_2e17_lhvloose_nod0
# AnalysisTrigMatch_HLT_2e17_lhvloose_nod0_ringer
# AnalysisTrigMatch_HLT_2g20_loose_g15_loose
# AnalysisTrigMatch_HLT_2g20_tight
# AnalysisTrigMatch_HLT_2g22_tight
# AnalysisTrigMatch_HLT_2g22_tight_L1EM7_EMPTY
# AnalysisTrigMatch_HLT_2g22_tight_L1EM7_UNPAIRED_ISO
# AnalysisTrigMatch_HLT_2g50_loose_L12EM20VH
# AnalysisTrigMatch_HLT_2mu10
# AnalysisTrigMatch_HLT_2mu10_nomucomb
# AnalysisTrigMatch_HLT_2mu14
# AnalysisTrigMatch_HLT_2mu14_nomucomb
# AnalysisTrigMatch_HLT_2mu20_L12MU20_OVERLAY
# AnalysisTrigMatch_HLT_2mu4_bJpsimumu
# AnalysisTrigMatch_HLT_2mu4_bUpsimumu
# AnalysisTrigMatch_HLT_2mu6_10invm30_pt2_z10
# AnalysisTrigMatch_HLT_2mu6_bJpsimumu
# AnalysisTrigMatch_HLT_2mu6_bJpsimumu_delayed
# AnalysisTrigMatch_HLT_2mu6_bUpsimumu
# AnalysisTrigMatch_HLT_2mu6_bUpsimumu_delayed
# AnalysisTrigMatch_HLT_3g15_loose
# AnalysisTrigMatch_HLT_3g20_loose
# AnalysisTrigMatch_HLT_3mu4
# AnalysisTrigMatch_HLT_3mu4_nomucomb
# AnalysisTrigMatch_HLT_3mu6
# AnalysisTrigMatch_HLT_3mu6_msonly
# AnalysisTrigMatch_HLT_3mu6_msonly_L1MU4_UNPAIRED_ISO
# AnalysisTrigMatch_HLT_3mu6_msonly_L1MU6_EMPTY
# AnalysisTrigMatch_HLT_e100_lhvloose_nod0
# AnalysisTrigMatch_HLT_e10_lhvloose_L1EM7
# AnalysisTrigMatch_HLT_e10_lhvloose_nod0_L1EM7
# AnalysisTrigMatch_HLT_e120_lhloose
# AnalysisTrigMatch_HLT_e120_lhloose_nod0
# AnalysisTrigMatch_HLT_e120_lhvloose_nod0
# AnalysisTrigMatch_HLT_e12_lhloose_2mu10
# AnalysisTrigMatch_HLT_e12_lhloose_nod0_2mu10
# AnalysisTrigMatch_HLT_e12_lhvloose_L1EM10VH
# AnalysisTrigMatch_HLT_e12_lhvloose_nod0_L1EM10VH
# AnalysisTrigMatch_HLT_e140_lhloose_nod0
# AnalysisTrigMatch_HLT_e140_lhloose_nod0_ringer
# AnalysisTrigMatch_HLT_e140_lhvloose_nod0
# AnalysisTrigMatch_HLT_e15_lhvloose_L1EM13VH
# AnalysisTrigMatch_HLT_e15_lhvloose_nod0_L1EM7
# AnalysisTrigMatch_HLT_e17_lhloose_2e9_lhloose
# AnalysisTrigMatch_HLT_e17_lhloose_mu14
# AnalysisTrigMatch_HLT_e17_lhloose_nod0_2e12_lhloose_nod0_L1EM15VH_3EM10VH
# AnalysisTrigMatch_HLT_e17_lhloose_nod0_2e9_lhloose_nod0
# AnalysisTrigMatch_HLT_e17_lhloose_nod0_mu14
# AnalysisTrigMatch_HLT_e17_lhmedium_iloose_2e9_lhmedium
# AnalysisTrigMatch_HLT_e17_lhmedium_iloose_tau25_medium1_tracktwo
# AnalysisTrigMatch_HLT_e17_lhmedium_nod0_iloose_2e9_lhmedium_nod0
# AnalysisTrigMatch_HLT_e17_lhmedium_nod0_iloose_tau25_medium1_tracktwo
# AnalysisTrigMatch_HLT_e17_lhmedium_nod0_ivarloose_tau25_medium1_tracktwo
# AnalysisTrigMatch_HLT_e17_lhmedium_nod0_ivarloose_tau25_medium1_tracktwo_L1DR-EM15TAU12I-J25
# AnalysisTrigMatch_HLT_e17_lhmedium_nod0_tau25_medium1_tracktwo
# AnalysisTrigMatch_HLT_e17_lhmedium_nod0_tau80_medium1_tracktwo
# AnalysisTrigMatch_HLT_e17_lhmedium_tau25_medium1_tracktwo
# AnalysisTrigMatch_HLT_e17_lhmedium_tau80_medium1_tracktwo
# AnalysisTrigMatch_HLT_e17_lhvloose
# AnalysisTrigMatch_HLT_e17_lhvloose_nod0
# AnalysisTrigMatch_HLT_e200_etcut
# AnalysisTrigMatch_HLT_e20_lhvloose
# AnalysisTrigMatch_HLT_e20_lhvloose_nod0
# AnalysisTrigMatch_HLT_e22_lhvloose_nod0_e12_lhvloose_nod0_e10_lhvloose_nod0_L1EM20VH_2EM10VH_3EM8VH
# AnalysisTrigMatch_HLT_e24_lhmedium_L1EM20VH
# AnalysisTrigMatch_HLT_e24_lhmedium_L1EM20VHI_mu8noL1
# AnalysisTrigMatch_HLT_e24_lhmedium_iloose_L1EM20VH
# AnalysisTrigMatch_HLT_e24_lhmedium_nod0_L1EM20VHI_mu8noL1
# AnalysisTrigMatch_HLT_e24_lhmedium_nod0_iloose_L1EM20VH
# AnalysisTrigMatch_HLT_e24_lhmedium_nod0_ivarloose_tau35_medium1_tracktwo
# AnalysisTrigMatch_HLT_e24_lhtight_nod0_ivarloose
# AnalysisTrigMatch_HLT_e24_lhvloose_nod0_L1EM18VH
# AnalysisTrigMatch_HLT_e26_lhmedium_L1EM22VHI_mu8noL1
# AnalysisTrigMatch_HLT_e26_lhmedium_nod0_L1EM22VHI_mu8noL1
# AnalysisTrigMatch_HLT_e26_lhtight_cutd0dphideta_ivarloose
# AnalysisTrigMatch_HLT_e26_lhtight_ivarloose
# AnalysisTrigMatch_HLT_e26_lhtight_nod0
# AnalysisTrigMatch_HLT_e26_lhtight_nod0_e15_etcut_L1EM7_Zee
# AnalysisTrigMatch_HLT_e26_lhtight_nod0_ivarloose
# AnalysisTrigMatch_HLT_e26_lhtight_nod0_ringer_ivarloose
# AnalysisTrigMatch_HLT_e26_lhtight_smooth_ivarloose
# AnalysisTrigMatch_HLT_e26_lhvloose_nod0_L1EM20VH
# AnalysisTrigMatch_HLT_e28_lhtight_nod0_L1EM22VHI
# AnalysisTrigMatch_HLT_e28_lhtight_nod0_ringer_ivarloose
# AnalysisTrigMatch_HLT_e28_lhvloose_nod0_L1EM20VH
# AnalysisTrigMatch_HLT_e300_etcut
# AnalysisTrigMatch_HLT_e5_lhvloose
# AnalysisTrigMatch_HLT_e5_lhvloose_nod0
# AnalysisTrigMatch_HLT_e60_lhmedium
# AnalysisTrigMatch_HLT_e60_lhmedium_L1EM24VHI
# AnalysisTrigMatch_HLT_e60_lhmedium_nod0
# AnalysisTrigMatch_HLT_e60_lhmedium_nod0_ringer
# AnalysisTrigMatch_HLT_e60_lhvloose_nod0
# AnalysisTrigMatch_HLT_e60_medium
# AnalysisTrigMatch_HLT_e70_lhvloose_nod0
# AnalysisTrigMatch_HLT_e7_lhmedium_mu24
# AnalysisTrigMatch_HLT_e7_lhmedium_nod0_mu24
# AnalysisTrigMatch_HLT_e80_lhvloose_nod0
# AnalysisTrigMatch_HLT_g120_loose
# AnalysisTrigMatch_HLT_g140_loose
# AnalysisTrigMatch_HLT_g200_etcut
# AnalysisTrigMatch_HLT_g300_etcut
# AnalysisTrigMatch_HLT_g35_loose_g25_loose
# AnalysisTrigMatch_HLT_g35_loose_g25_loose_L12EM20VH
# AnalysisTrigMatch_HLT_g35_medium_g25_medium_L12EM20VH
# AnalysisTrigMatch_HLT_g35_medium_g25_medium_L1EM7_EMPTY
# AnalysisTrigMatch_HLT_g35_medium_g25_medium_L1EM7_UNPAIRED_ISO
# AnalysisTrigMatch_HLT_id_cosmicid_L1MU11_EMPTY
# AnalysisTrigMatch_HLT_mu10
# AnalysisTrigMatch_HLT_mu10_bJpsi_Trkloose
# AnalysisTrigMatch_HLT_mu11_2mu4noL1_nscan03_L1MU11_2MU6
# AnalysisTrigMatch_HLT_mu11_L1MU10_2mu4noL1_nscan03_L1MU10_2MU6
# AnalysisTrigMatch_HLT_mu11_nomucomb_2mu4noL1_nscan03_L1MU11_2MU6
# AnalysisTrigMatch_HLT_mu11_nomucomb_2mu4noL1_nscan03_L1MU11_2MU6_bTau
# AnalysisTrigMatch_HLT_mu11_nomucomb_mu6noL1_nscan03_L1MU11_2MU6_bTau
# AnalysisTrigMatch_HLT_mu11_nomucomb_mu6noL1_nscan03_L1MU11_2MU6_bTau_delayed
# AnalysisTrigMatch_HLT_mu13_mu13_idperf_Zmumu
# AnalysisTrigMatch_HLT_mu14
# AnalysisTrigMatch_HLT_mu14_iloose_tau25_medium1_tracktwo
# AnalysisTrigMatch_HLT_mu14_iloose_tau35_medium1_tracktwo
# AnalysisTrigMatch_HLT_mu14_ivarloose_L1MU11_tau35_medium1_tracktwo_L1MU11_TAU20IM
# AnalysisTrigMatch_HLT_mu14_ivarloose_tau25_medium1_tracktwo
# AnalysisTrigMatch_HLT_mu14_ivarloose_tau25_medium1_tracktwo_L1DR-MU10TAU12I_TAU12I-J25
# AnalysisTrigMatch_HLT_mu14_ivarloose_tau35_medium1_tracktwo
# AnalysisTrigMatch_HLT_mu14_tau25_medium1_tracktwo
# AnalysisTrigMatch_HLT_mu14_tau35_medium1_tracktwo
# AnalysisTrigMatch_HLT_mu18
# AnalysisTrigMatch_HLT_mu18_2mu0noL1_JpsimumuFS
# AnalysisTrigMatch_HLT_mu18_2mu4_JpsimumuL2
# AnalysisTrigMatch_HLT_mu18_2mu4noL1
# AnalysisTrigMatch_HLT_mu18_mu8noL1
# AnalysisTrigMatch_HLT_mu20
# AnalysisTrigMatch_HLT_mu20_2mu0noL1_JpsimumuFS
# AnalysisTrigMatch_HLT_mu20_2mu4_JpsimumuL2
# AnalysisTrigMatch_HLT_mu20_2mu4noL1
# AnalysisTrigMatch_HLT_mu20_iloose_L1MU15
# AnalysisTrigMatch_HLT_mu20_ivarmedium_mu8noL1
# AnalysisTrigMatch_HLT_mu20_l2idonly_mu6noL1_nscan03
# AnalysisTrigMatch_HLT_mu20_msonly_mu10noL1_msonly_nscan05_noComb
# AnalysisTrigMatch_HLT_mu20_msonly_mu10noL1_msonly_nscan05_noComb_L1MU4_UNPAIRED_ISO
# AnalysisTrigMatch_HLT_mu20_msonly_mu10noL1_msonly_nscan05_noComb_L1MU6_EMPTY
# AnalysisTrigMatch_HLT_mu20_msonly_mu15noL1_msonly_nscan05_noComb
# AnalysisTrigMatch_HLT_mu20_msonly_mu15noL1_msonly_nscan05_noComb_L1MU4_UNPAIRED_ISO
# AnalysisTrigMatch_HLT_mu20_msonly_mu15noL1_msonly_nscan05_noComb_L1MU6_EMPTY
# AnalysisTrigMatch_HLT_mu20_msonly_mu6noL1_msonly_nscan05
# AnalysisTrigMatch_HLT_mu20_mu8noL1
# AnalysisTrigMatch_HLT_mu20_nomucomb_mu6noL1_nscan03
# AnalysisTrigMatch_HLT_mu22
# AnalysisTrigMatch_HLT_mu22_mu8noL1
# AnalysisTrigMatch_HLT_mu22_mu8noL1_calotag_0eta010
# AnalysisTrigMatch_HLT_mu24
# AnalysisTrigMatch_HLT_mu24_iloose
# AnalysisTrigMatch_HLT_mu24_imedium
# AnalysisTrigMatch_HLT_mu24_ivarloose
# AnalysisTrigMatch_HLT_mu24_ivarmedium
# AnalysisTrigMatch_HLT_mu26_ivarmedium
# AnalysisTrigMatch_HLT_mu4
# AnalysisTrigMatch_HLT_mu40
# AnalysisTrigMatch_HLT_mu4_bJpsi_Trkloose
# AnalysisTrigMatch_HLT_mu4_j15_bperf_split_dr05_dz02
# AnalysisTrigMatch_HLT_mu4_j15_dr05
# AnalysisTrigMatch_HLT_mu4_j25_bperf_split_dr05_dz02
# AnalysisTrigMatch_HLT_mu4_j25_dr05
# AnalysisTrigMatch_HLT_mu4_j35_bperf_split_dr05_dz02
# AnalysisTrigMatch_HLT_mu4_j35_dr05
# AnalysisTrigMatch_HLT_mu4_j55_bperf_split_dr05_dz02
# AnalysisTrigMatch_HLT_mu4_j55_dr05
# AnalysisTrigMatch_HLT_mu4_mu4_idperf_bJpsimumu_noid
# AnalysisTrigMatch_HLT_mu50
# AnalysisTrigMatch_HLT_mu6
# AnalysisTrigMatch_HLT_mu60_0eta105_msonly
# AnalysisTrigMatch_HLT_mu6_2mu4
# AnalysisTrigMatch_HLT_mu6_bJpsi_Trkloose
# AnalysisTrigMatch_HLT_mu6_idperf
# AnalysisTrigMatch_HLT_mu6_iloose_mu6_11invm24_noos
# AnalysisTrigMatch_HLT_mu6_j110_bperf_split_dr05_dz02
# AnalysisTrigMatch_HLT_mu6_j110_dr05
# AnalysisTrigMatch_HLT_mu6_j150_bperf_split_dr05_dz02
# AnalysisTrigMatch_HLT_mu6_j150_dr05
# AnalysisTrigMatch_HLT_mu6_j175_bperf_split_dr05_dz02
# AnalysisTrigMatch_HLT_mu6_j175_dr05
# AnalysisTrigMatch_HLT_mu6_j85_bperf_split_dr05_dz02
# AnalysisTrigMatch_HLT_mu6_j85_dr05
# AnalysisTrigMatch_HLT_mu6_mu4_bJpsimumu
# AnalysisTrigMatch_HLT_mu6_mu4_bJpsimumu_delayed
# AnalysisTrigMatch_HLT_mu6_mu4_bUpsimumu
# AnalysisTrigMatch_HLT_mu6_mu4_bUpsimumu_delayed
# AnalysisTrigMatch_HLT_mu6_nomucomb_2mu4_nomucomb_L1MU6_3MU4
# AnalysisTrigMatch_HLT_mu6_nomucomb_2mu4_nomucomb_delayed_L1MU6_3MU4
# index_ref
# AnalysisJetsAuxDyn.pt
# AnalysisJetsAuxDyn.eta
# AnalysisJetsAuxDyn.phi
# AnalysisJetsAuxDyn.m
# AnalysisJetsAuxDyn.JetConstitScaleMomentum_pt
# AnalysisJetsAuxDyn.JetConstitScaleMomentum_eta
# AnalysisJetsAuxDyn.JetConstitScaleMomentum_phi
# AnalysisJetsAuxDyn.JetConstitScaleMomentum_m
# AnalysisJetsAuxDyn.btaggingLink
# AnalysisJetsAuxDyn.btaggingLink/AnalysisJetsAuxDyn.btaggingLink.m_persKey
# AnalysisJetsAuxDyn.btaggingLink/AnalysisJetsAuxDyn.btaggingLink.m_persIndex
# AnalysisJetsAuxDyn.ActiveArea4vec_eta
# AnalysisJetsAuxDyn.ActiveArea4vec_m
# AnalysisJetsAuxDyn.ActiveArea4vec_phi
# AnalysisJetsAuxDyn.ActiveArea4vec_pt
# AnalysisJetsAuxDyn.DetectorEta
# AnalysisJetsAuxDyn.EMFrac
# AnalysisJetsAuxDyn.JVFCorr
# AnalysisJetsAuxDyn.Timing
# AnalysisJetsAuxDyn.NumTrkPt1000
# AnalysisJetsAuxDyn.NumTrkPt500
# AnalysisJetsAuxDyn.EnergyPerSampling
# AnalysisJetsAuxDyn.SumPtChargedPFOPt500
# AnalysisJetsAuxDyn.SumPtTrkPt500
# AnalysisJetsAuxDyn.TrackWidthPt1000
# AnalysisJetsAuxDyn.PSFrac
# AnalysisJetsAuxDyn.Width
# AnalysisJetsAuxDyn.DFCommonJets_fJvt
# AnalysisJetsAuxDyn.HadronConeExclTruthLabelID
# AnalysisJetsAuxDyn.HadronConeExclExtendedTruthLabelID
# AnalysisJetsAuxDyn.isJvtHS
# AnalysisJetsAuxDyn.GhostTrack
# AnalysisJetsAuxDyn.PartonTruthLabelID
# AnalysisJetsAuxDyn.ConeTruthLabelID
# AnalysisJetsAuxDyn.GhostMuonSegmentCount
# AnalysisJetsAuxDyn.DFCommonJets_QGTagger_NTracks
# AnalysisJetsAuxDyn.DFCommonJets_QGTagger_TracksWidth
# AnalysisJetsAuxDyn.DFCommonJets_QGTagger_TracksC1
# AnalysisJetsAuxDyn.NNJvtPass
# AnalysisMuonsAuxDyn.pt
# AnalysisMuonsAuxDyn.eta
# AnalysisMuonsAuxDyn.phi
# AnalysisMuonsAuxDyn.muonSegmentLinks
# AnalysisMuonsAuxDyn.charge
# AnalysisMuonsAuxDyn.ptcone20
# AnalysisMuonsAuxDyn.ptvarcone20
# AnalysisMuonsAuxDyn.ptcone30
# AnalysisMuonsAuxDyn.ptvarcone30
# AnalysisMuonsAuxDyn.topoetcone20
# AnalysisMuonsAuxDyn.topoetcone40
# AnalysisMuonsAuxDyn.EnergyLoss
# AnalysisMuonsAuxDyn.MuonSpectrometerPt
# AnalysisMuonsAuxDyn.InnerDetectorPt
# AnalysisMuonsAuxDyn.truthType
# AnalysisMuonsAuxDyn.truthOrigin
# AnalysisMuonsAuxDyn.truthParticleLink
# AnalysisMuonsAuxDyn.truthParticleLink/AnalysisMuonsAuxDyn.truthParticleLink.m_persKey
# AnalysisMuonsAuxDyn.truthParticleLink/AnalysisMuonsAuxDyn.truthParticleLink.m_persIndex
# AnalysisMuonsAuxDyn.momentumBalanceSignificance
# AnalysisMuonsAuxDyn.scatteringNeighbourSignificance
# AnalysisMuonsAuxDyn.segmentDeltaEta
# AnalysisMuonsAuxDyn.CaloMuonScore
# AnalysisMuonsAuxDyn.ptvarcone30_Nonprompt_All_MaxWeightTTVA_pt500
# AnalysisMuonsAuxDyn.neflowisol20
# AnalysisMuonsAuxDyn.ptvarcone30_Nonprompt_All_MaxWeightTTVA_pt1000
# AnalysisMuonsAuxDyn.topoetcone20_CloseByCorr
# AnalysisMuonsAuxDyn.ptvarcone30_Nonprompt_All_MaxWeightTTVA_pt500_CloseByCorr
# AnalysisMuonsAuxDyn.neflowisol20_CloseByCorr
# AnalysisMuonsAuxDyn.ptvarcone30_Nonprompt_All_MaxWeightTTVA_pt1000_CloseByCorr
# AnalysisMuonsAuxDyn.TruthLink
# AnalysisMuonsAuxDyn.TruthLink/AnalysisMuonsAuxDyn.TruthLink.m_persKey
# AnalysisMuonsAuxDyn.TruthLink/AnalysisMuonsAuxDyn.TruthLink.m_persIndex
# AnalysisMuonsAuxDyn.author
# AnalysisMuonsAuxDyn.topoetcone30
# AnalysisMuonsAuxDyn.allAuthors
# AnalysisMuonsAuxDyn.muonType
# AnalysisMuonsAuxDyn.quality
# AnalysisMuonsAuxDyn.energyLossType
# AnalysisMuonsAuxDyn.numberOfPrecisionLayers
# AnalysisMuonsAuxDyn.numberOfPrecisionHoleLayers
# AnalysisMuonsAuxDyn.innerSmallHits
# AnalysisMuonsAuxDyn.innerLargeHits
# AnalysisMuonsAuxDyn.middleSmallHits
# AnalysisMuonsAuxDyn.middleLargeHits
# AnalysisMuonsAuxDyn.outerSmallHits
# AnalysisMuonsAuxDyn.outerLargeHits
# AnalysisMuonsAuxDyn.extendedSmallHits
# AnalysisMuonsAuxDyn.extendedLargeHits
# AnalysisMuonsAuxDyn.innerSmallHoles
# AnalysisMuonsAuxDyn.innerLargeHoles
# AnalysisMuonsAuxDyn.middleSmallHoles
# AnalysisMuonsAuxDyn.middleLargeHoles
# AnalysisMuonsAuxDyn.outerSmallHoles
# AnalysisMuonsAuxDyn.outerLargeHoles
# AnalysisMuonsAuxDyn.extendedSmallHoles
# AnalysisMuonsAuxDyn.extendedLargeHoles
# AnalysisMuonsAuxDyn.cscEtaHits
# AnalysisMuonsAuxDyn.cscUnspoiledEtaHits
# AnalysisMuonsAuxDyn.inDetTrackParticleLink
# AnalysisMuonsAuxDyn.inDetTrackParticleLink/AnalysisMuonsAuxDyn.inDetTrackParticleLink.m_persKey
# AnalysisMuonsAuxDyn.inDetTrackParticleLink/AnalysisMuonsAuxDyn.inDetTrackParticleLink.m_persIndex
# AnalysisMuonsAuxDyn.muonSpectrometerTrackParticleLink
# AnalysisMuonsAuxDyn.muonSpectrometerTrackParticleLink/AnalysisMuonsAuxDyn.muonSpectrometerTrackParticleLink.m_persKey
# AnalysisMuonsAuxDyn.muonSpectrometerTrackParticleLink/AnalysisMuonsAuxDyn.muonSpectrometerTrackParticleLink.m_persIndex
# AnalysisMuonsAuxDyn.extrapolatedMuonSpectrometerTrackParticleLink
# AnalysisMuonsAuxDyn.extrapolatedMuonSpectrometerTrackParticleLink/AnalysisMuonsAuxDyn.extrapolatedMuonSpectrometerTrackParticleLink.m_persKey
# AnalysisMuonsAuxDyn.extrapolatedMuonSpectrometerTrackParticleLink/AnalysisMuonsAuxDyn.extrapolatedMuonSpectrometerTrackParticleLink.m_persIndex
# AnalysisMuonsAuxDyn.msOnlyExtrapolatedMuonSpectrometerTrackParticleLink
# AnalysisMuonsAuxDyn.msOnlyExtrapolatedMuonSpectrometerTrackParticleLink/AnalysisMuonsAuxDyn.msOnlyExtrapolatedMuonSpectrometerTrackParticleLink.m_persKey
# AnalysisMuonsAuxDyn.msOnlyExtrapolatedMuonSpectrometerTrackParticleLink/AnalysisMuonsAuxDyn.msOnlyExtrapolatedMuonSpectrometerTrackParticleLink.m_persIndex
# AnalysisMuonsAuxDyn.combinedTrackParticleLink
# AnalysisMuonsAuxDyn.combinedTrackParticleLink/AnalysisMuonsAuxDyn.combinedTrackParticleLink.m_persKey
# AnalysisMuonsAuxDyn.combinedTrackParticleLink/AnalysisMuonsAuxDyn.combinedTrackParticleLink.m_persIndex
# AnalysisMuonsAuxDyn.clusterLink
# AnalysisMuonsAuxDyn.clusterLink/AnalysisMuonsAuxDyn.clusterLink.m_persKey
# AnalysisMuonsAuxDyn.clusterLink/AnalysisMuonsAuxDyn.clusterLink.m_persIndex
# AnalysisMuonsAuxDyn.spectrometerFieldIntegral
# AnalysisMuonsAuxDyn.scatteringCurvatureSignificance
# AnalysisMuonsAuxDyn.CaloLRLikelihood
# AnalysisMuonsAuxDyn.CaloMuonIDTag
# AnalysisMuonsAuxDyn.combinedTrackOutBoundsPrecisionHits
# AnalysisMuonsAuxDyn.extendedClosePrecisionHits
# AnalysisMuonsAuxDyn.extendedOutBoundsPrecisionHits
# AnalysisMuonsAuxDyn.innerClosePrecisionHits
# AnalysisMuonsAuxDyn.innerOutBoundsPrecisionHits
# AnalysisMuonsAuxDyn.isEndcapGoodLayers
# AnalysisMuonsAuxDyn.isSmallGoodSectors
# AnalysisMuonsAuxDyn.middleClosePrecisionHits
# AnalysisMuonsAuxDyn.middleOutBoundsPrecisionHits
# AnalysisMuonsAuxDyn.numberOfGoodPrecisionLayers
# AnalysisMuonsAuxDyn.outerClosePrecisionHits
# AnalysisMuonsAuxDyn.outerOutBoundsPrecisionHits
# AnalysisMuonsAuxDyn.ptcone40
# AnalysisMuonsAuxDyn.ptvarcone40
# AnalysisMuonsAuxDyn.DFCommonMuonPassIDCuts
# AnalysisMuonsAuxDyn.DFCommonMuonPassPreselection
# AnalysisMuonsAuxDyn.ptcone20_Nonprompt_All_MaxWeightTTVA_pt500
# AnalysisMuonsAuxDyn.ptcone20_Nonprompt_All_MaxWeightTTVA_pt1000
# AnalysisMuonsAuxDyn.DFCommonJetDr
# AnalysisPhotonsAuxDyn.ambiguityLink
# AnalysisPhotonsAuxDyn.ambiguityLink/AnalysisPhotonsAuxDyn.ambiguityLink.m_persKey
# AnalysisPhotonsAuxDyn.ambiguityLink/AnalysisPhotonsAuxDyn.ambiguityLink.m_persIndex
# AnalysisPhotonsAuxDyn.pt
# AnalysisPhotonsAuxDyn.eta
# AnalysisPhotonsAuxDyn.phi
# AnalysisPhotonsAuxDyn.m
# AnalysisPhotonsAuxDyn.ptcone20
# AnalysisPhotonsAuxDyn.topoetcone20
# AnalysisPhotonsAuxDyn.topoetcone40
# AnalysisPhotonsAuxDyn.f1
# AnalysisPhotonsAuxDyn.truthType
# AnalysisPhotonsAuxDyn.truthOrigin
# AnalysisPhotonsAuxDyn.truthParticleLink
# AnalysisPhotonsAuxDyn.truthParticleLink/AnalysisPhotonsAuxDyn.truthParticleLink.m_persKey
# AnalysisPhotonsAuxDyn.truthParticleLink/AnalysisPhotonsAuxDyn.truthParticleLink.m_persIndex
# AnalysisPhotonsAuxDyn.topoetcone20_CloseByCorr
# AnalysisPhotonsAuxDyn.ptcone20_CloseByCorr
# AnalysisPhotonsAuxDyn.topoetcone40_CloseByCorr
# AnalysisPhotonsAuxDyn.DFCommonPhotonsCleaning
# AnalysisPhotonsAuxDyn.DFCommonPhotonsIsEMLoose
# AnalysisPhotonsAuxDyn.TruthLink
# AnalysisPhotonsAuxDyn.TruthLink/AnalysisPhotonsAuxDyn.TruthLink.m_persKey
# AnalysisPhotonsAuxDyn.TruthLink/AnalysisPhotonsAuxDyn.TruthLink.m_persIndex
# AnalysisPhotonsAuxDyn.caloClusterLinks
# AnalysisPhotonsAuxDyn.author
# AnalysisPhotonsAuxDyn.OQ
# AnalysisPhotonsAuxDyn.topoetcone20ptCorrection
# AnalysisPhotonsAuxDyn.topoetcone40ptCorrection
# AnalysisPhotonsAuxDyn.vertexLinks
# AnalysisPhotonsAuxDyn.DFCommonPhotonsIsEMTight
# AnalysisPhotonsAuxDyn.DFCommonPhotonsIsEMTightIsEMValue
# AnalysisPhotonsAuxDyn.DFCommonPhotonsCleaningNoTime
# AnalysisSiHitElectronsAuxDyn.pt
# AnalysisSiHitElectronsAuxDyn.eta
# AnalysisSiHitElectronsAuxDyn.phi
# AnalysisSiHitElectronsAuxDyn.m
# AnalysisSiHitElectronsAuxDyn.charge
# AnalysisSiHitElectronsAuxDyn.truthType
# AnalysisSiHitElectronsAuxDyn.truthOrigin
# AnalysisSiHitElectronsAuxDyn.ptvarcone30_Nonprompt_All_MaxWeightTTVALooseCone_pt1000_CloseByCorr
# AnalysisSiHitElectronsAuxDyn.topoetcone20_CloseByCorr
# AnalysisSiHitElectronsAuxDyn.z0stheta
# AnalysisSiHitElectronsAuxDyn.d0Normalized
# AnalysisSiHitElectronsAuxDyn.nInnerExpPix
# AnalysisSiHitElectronsAuxDyn.clEta
# AnalysisSiHitElectronsAuxDyn.clPhi
# AnalysisSiHitElectronsAuxDyn.author
# AnalysisSiHitElectronsAuxDyn.OQ
# AnalysisSiHitElectronsAuxDyn.DFCommonElectronsLHVeryLoose
# AnalysisSiHitElectronsAuxDyn.firstEgMotherTruthType
# AnalysisSiHitElectronsAuxDyn.firstEgMotherTruthOrigin
# AnalysisTauJetsAuxDyn.pt
# AnalysisTauJetsAuxDyn.eta
# AnalysisTauJetsAuxDyn.phi
# AnalysisTauJetsAuxDyn.m
# AnalysisTauJetsAuxDyn.vertexLink
# AnalysisTauJetsAuxDyn.vertexLink/AnalysisTauJetsAuxDyn.vertexLink.m_persKey
# AnalysisTauJetsAuxDyn.vertexLink/AnalysisTauJetsAuxDyn.vertexLink.m_persIndex
# AnalysisTauJetsAuxDyn.tauTrackLinks
# AnalysisTauJetsAuxDyn.charge
# AnalysisTauJetsAuxDyn.EleRNNLoose_v1
# AnalysisTauJetsAuxDyn.EleRNNMedium_v1
# AnalysisTauJetsAuxDyn.EleRNNTight_v1
# AnalysisTauJetsAuxDyn.JetDeepSetVeryLoose
# AnalysisTauJetsAuxDyn.JetDeepSetLoose
# AnalysisTauJetsAuxDyn.JetDeepSetMedium
# AnalysisTauJetsAuxDyn.JetDeepSetTight
# AnalysisTauJetsAuxDyn.truthParticleLink
# AnalysisTauJetsAuxDyn.truthParticleLink/AnalysisTauJetsAuxDyn.truthParticleLink.m_persKey
# AnalysisTauJetsAuxDyn.truthParticleLink/AnalysisTauJetsAuxDyn.truthParticleLink.m_persIndex
# AnalysisTauJetsAuxDyn.IsTruthMatched
# AnalysisTauJetsAuxDyn.ptTauEnergyScale
# AnalysisTauJetsAuxDyn.etaTauEnergyScale
# AnalysisTauJetsAuxDyn.ptFinalCalib
# AnalysisTauJetsAuxDyn.etaFinalCalib
# AnalysisTauJetsAuxDyn.isTauFlags
# AnalysisTauJetsAuxDyn.PanTau_DecayMode
# AnalysisTauJetsAuxDyn.RNNJetScore
# AnalysisTauJetsAuxDyn.RNNJetScoreSigTrans
# AnalysisTauJetsAuxDyn.RNNEleScore
# AnalysisTauJetsAuxDyn.NNDecayMode
# AnalysisTauJetsAuxDyn.truthJetLink
# AnalysisTauJetsAuxDyn.truthJetLink/AnalysisTauJetsAuxDyn.truthJetLink.m_persKey
# AnalysisTauJetsAuxDyn.truthJetLink/AnalysisTauJetsAuxDyn.truthJetLink.m_persIndex
# AnalysisTauJetsAuxDyn.RNNEleScoreSigTrans_v1
# AnalysisTauJetsAuxDyn.JetDeepSetScore
# AnalysisTauJetsAuxDyn.JetDeepSetScoreTrans
# AnalysisTrigMatch_HLT_2mu10AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_2mu10_nomucombAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_2mu14AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_2mu14_nomucombAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_3mu4AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_3mu4_nomucombAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_3mu6AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_3mu6_msonlyAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu10AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu14AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu18AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu20AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu20_iloose_L1MU15AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu22AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu24AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu24_ilooseAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu24_imediumAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu24_ivarlooseAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu24_ivarmediumAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu26_ivarmediumAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu40AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu4AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu4_bJpsi_TrklooseAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu4_j15_bperf_split_dr05_dz02AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu4_j25_bperf_split_dr05_dz02AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu4_j35_bperf_split_dr05_dz02AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu50AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu6AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu6_2mu4AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu6_bJpsi_TrklooseAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu6_idperfAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu6_nomucomb_2mu4_nomucomb_L1MU6_3MU4AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu6_nomucomb_2mu4_nomucomb_delayed_L1MU6_3MU4AuxDyn.TrigMatchedObjects
# AntiKt10TruthSoftDropBeta100Zcut10JetsAuxDyn.D2
# AntiKt10TruthSoftDropBeta100Zcut10JetsAuxDyn.Tau1_wta
# AntiKt10TruthSoftDropBeta100Zcut10JetsAuxDyn.Tau2_wta
# AntiKt10TruthSoftDropBeta100Zcut10JetsAuxDyn.Tau3_wta
# AntiKt4TruthDressedWZJetsAuxDyn.HadronConeExclTruthLabelID
# AntiKt4TruthDressedWZJetsAuxDyn.GhostCHadronsFinalCount
# AntiKt4TruthDressedWZJetsAuxDyn.GhostBHadronsFinalCount
# AntiKt4TruthDressedWZJetsAuxDyn.PartonTruthLabelID
# AntiKt4TruthDressedWZJetsAuxDyn.ConeTruthLabelID
# AntiKt4TruthDressedWZJetsAuxDyn.TrueFlavor
# BTagging_AntiKt4EMPFlowAuxDyn.DL1dv01_pu
# BTagging_AntiKt4EMPFlowAuxDyn.DL1dv01_pc
# BTagging_AntiKt4EMPFlowAuxDyn.DL1dv01_pb
# BTagging_AntiKt4EMPFlowAuxDyn.GN2v00_pc
# BTagging_AntiKt4EMPFlowAuxDyn.GN2v00_pb
# BTagging_AntiKt4EMPFlowAuxDyn.GN2v00_pu
# BTagging_AntiKtVR30Rmax4Rmin02TrackAuxDyn.DL1dv01_pu
# BTagging_AntiKtVR30Rmax4Rmin02TrackAuxDyn.DL1dv01_pc
# BTagging_AntiKtVR30Rmax4Rmin02TrackAuxDyn.DL1dv01_pb
# BTagging_AntiKtVR30Rmax4Rmin02TrackAuxDyn.GN2v00_pc
# BTagging_AntiKtVR30Rmax4Rmin02TrackAuxDyn.GN2v00_pb
# BTagging_AntiKtVR30Rmax4Rmin02TrackAuxDyn.GN2v00_pu
# BornLeptonsAuxDyn.prodVtxLink
# BornLeptonsAuxDyn.prodVtxLink/BornLeptonsAuxDyn.prodVtxLink.m_persKey
# BornLeptonsAuxDyn.prodVtxLink/BornLeptonsAuxDyn.prodVtxLink.m_persIndex
# BornLeptonsAuxDyn.decayVtxLink
# BornLeptonsAuxDyn.decayVtxLink/BornLeptonsAuxDyn.decayVtxLink.m_persKey
# BornLeptonsAuxDyn.decayVtxLink/BornLeptonsAuxDyn.decayVtxLink.m_persIndex
# BornLeptonsAuxDyn.m
# BornLeptonsAuxDyn.px
# BornLeptonsAuxDyn.py
# BornLeptonsAuxDyn.pz
# BornLeptonsAuxDyn.e
# BornLeptonsAuxDyn.pdgId
# BornLeptonsAuxDyn.classifierParticleOrigin
# BornLeptonsAuxDyn.Classification
# BornLeptonsAuxDyn.barcode
# BornLeptonsAuxDyn.status
# BornLeptonsAuxDyn.classifierParticleType
# BornLeptonsAuxDyn.classifierParticleOutCome
# BornLeptonsAuxDyn.polarizationPhi
# BornLeptonsAuxDyn.polarizationTheta
# BornLeptonsAuxDyn.dressedPhoton
# BornLeptonsAuxDyn.unusedPhotonDecoration
# CombinedMuonTrackParticlesAuxDyn.definingParametersCovMatrixDiag
# CombinedMuonTrackParticlesAuxDyn.definingParametersCovMatrixOffDiag
# CombinedMuonTrackParticlesAuxDyn.phi
# CombinedMuonTrackParticlesAuxDyn.truthType
# CombinedMuonTrackParticlesAuxDyn.truthOrigin
# CombinedMuonTrackParticlesAuxDyn.numberOfPixelHits
# CombinedMuonTrackParticlesAuxDyn.numberOfPixelHoles
# CombinedMuonTrackParticlesAuxDyn.numberOfPixelDeadSensors
# CombinedMuonTrackParticlesAuxDyn.numberOfSCTHits
# CombinedMuonTrackParticlesAuxDyn.numberOfSCTHoles
# CombinedMuonTrackParticlesAuxDyn.numberOfSCTDeadSensors
# CombinedMuonTrackParticlesAuxDyn.qOverP
# CombinedMuonTrackParticlesAuxDyn.chiSquared
# CombinedMuonTrackParticlesAuxDyn.numberDoF
# CombinedMuonTrackParticlesAuxDyn.d0
# CombinedMuonTrackParticlesAuxDyn.z0
# CombinedMuonTrackParticlesAuxDyn.theta
# CombinedMuonTrackParticlesAuxDyn.vz
# CombinedMuonTrackParticlesAuxDyn.numberOfTRTHits
# CombinedMuonTrackParticlesAuxDyn.numberOfTRTOutliers
# EventInfoAuxDyn.eventNumber
# EventInfoAuxDyn.mcEventNumber
# EventInfoAuxDyn.pileUpMixtureIDLowBits
# EventInfoAuxDyn.pileUpMixtureIDHighBits
# EventInfoAuxDyn.actualInteractionsPerCrossing
# EventInfoAuxDyn.averageInteractionsPerCrossing
# EventInfoAuxDyn.beamSpotWeight
# EventInfoAuxDyn.RandomRunNumber
# EventInfoAuxDyn.GenFiltHT
# EventInfoAuxDyn.GenFiltHTinclNu
# EventInfoAuxDyn.GenFiltMET
# EventInfoAuxDyn.GenFiltPTZ
# EventInfoAuxDyn.GenFiltFatJ
# EventInfoAuxDyn.mcChannelNumber
# EventInfoAuxDyn.PileupWeight_NOSYS
# EventInfoAuxDyn.runNumber
# EventInfoAuxDyn.lumiBlock
# EventInfoAuxDyn.timeStamp
# EventInfoAuxDyn.timeStampNSOffset
# EventInfoAuxDyn.bcid
# EventInfoAuxDyn.detDescrTags
# EventInfoAuxDyn.detDescrTags/EventInfoAuxDyn.detDescrTags.first
# EventInfoAuxDyn.detDescrTags/EventInfoAuxDyn.detDescrTags.second
# EventInfoAuxDyn.eventTypeBitmask
# EventInfoAuxDyn.beamPosX
# EventInfoAuxDyn.beamPosY
# EventInfoAuxDyn.beamPosZ
# EventInfoAuxDyn.beamPosSigmaX
# EventInfoAuxDyn.beamPosSigmaY
# EventInfoAuxDyn.beamPosSigmaZ
# EventInfoAuxDyn.beamPosSigmaXY
# EventInfoAuxDyn.beamTiltXZ
# EventInfoAuxDyn.beamTiltYZ
# EventInfoAuxDyn.beamStatus
# EventInfoAuxDyn.pixelFlags
# EventInfoAuxDyn.sctFlags
# EventInfoAuxDyn.trtFlags
# EventInfoAuxDyn.larFlags
# EventInfoAuxDyn.tileFlags
# EventInfoAuxDyn.muonFlags
# EventInfoAuxDyn.forwardDetFlags
# EventInfoAuxDyn.coreFlags
# EventInfoAuxDyn.lumiFlags
# EventInfoAuxDyn.mcEventWeights
# EventInfoAuxDyn.hardScatterVertexLink
# EventInfoAuxDyn.hardScatterVertexLink/EventInfoAuxDyn.hardScatterVertexLink
# EventInfoAuxDyn.DFCommonJets_isBadBatman
# EventInfoAuxDyn.DFCommonJets_BCIDDistanceFromFront
# EventInfoAuxDyn.DFCommonJets_BCIDDistanceTail
# EventInfoAuxDyn.DFCommonJets_BCIDGapBeforeTrain
# EventInfoAuxDyn.DFCommonJets_BCIDGapAfterTrain
# EventInfoAuxDyn.DFCommonJets_BCIDType
# EventInfoAuxDyn.DFCommonJets_BCIDGapBeforeTrainMinus12
# EventInfoAuxDyn.DFCommonJets_BCIDGapAfterTrainMinus12
# EventInfoAuxDyn.DFCommonJets_BCIDTypeMinus12
# EventInfoAuxDyn.DFCommonJets_eventClean_LooseBad
# EventInfoAuxDyn.DFCommonJets_eventClean_LooseBadLLP
# EventInfoAuxDyn.HTXS_prodMode
# ExtrapolatedMuonTrackParticlesAuxDyn.definingParametersCovMatrixDiag
# ExtrapolatedMuonTrackParticlesAuxDyn.definingParametersCovMatrixOffDiag
# ExtrapolatedMuonTrackParticlesAuxDyn.phi
# ExtrapolatedMuonTrackParticlesAuxDyn.truthType
# ExtrapolatedMuonTrackParticlesAuxDyn.truthOrigin
# ExtrapolatedMuonTrackParticlesAuxDyn.qOverP
# ExtrapolatedMuonTrackParticlesAuxDyn.d0
# ExtrapolatedMuonTrackParticlesAuxDyn.z0
# ExtrapolatedMuonTrackParticlesAuxDyn.theta
# ExtrapolatedMuonTrackParticlesAuxDyn.vz
# HardScatterParticlesAuxDyn.prodVtxLink
# HardScatterParticlesAuxDyn.prodVtxLink/HardScatterParticlesAuxDyn.prodVtxLink.m_persKey
# HardScatterParticlesAuxDyn.prodVtxLink/HardScatterParticlesAuxDyn.prodVtxLink.m_persIndex
# HardScatterParticlesAuxDyn.decayVtxLink
# HardScatterParticlesAuxDyn.decayVtxLink/HardScatterParticlesAuxDyn.decayVtxLink.m_persKey
# HardScatterParticlesAuxDyn.decayVtxLink/HardScatterParticlesAuxDyn.decayVtxLink.m_persIndex
# HardScatterParticlesAuxDyn.m
# HardScatterParticlesAuxDyn.px
# HardScatterParticlesAuxDyn.py
# HardScatterParticlesAuxDyn.pz
# HardScatterParticlesAuxDyn.e
# HardScatterParticlesAuxDyn.pdgId
# HardScatterParticlesAuxDyn.classifierParticleOrigin
# HardScatterParticlesAuxDyn.barcode
# HardScatterParticlesAuxDyn.status
# HardScatterParticlesAuxDyn.classifierParticleType
# HardScatterParticlesAuxDyn.classifierParticleOutCome
# HardScatterVerticesAuxDyn.incomingParticleLinks
# HardScatterVerticesAuxDyn.outgoingParticleLinks
# HardScatterVerticesAuxDyn.barcode
# HardScatterVerticesAuxDyn.id
# HardScatterVerticesAuxDyn.x
# HardScatterVerticesAuxDyn.y
# HardScatterVerticesAuxDyn.z
# HardScatterVerticesAuxDyn.t
# InDetTrackParticlesAuxDyn.definingParametersCovMatrixDiag
# InDetTrackParticlesAuxDyn.definingParametersCovMatrixOffDiag
# InDetTrackParticlesAuxDyn.phi
# InDetTrackParticlesAuxDyn.truthParticleLink
# InDetTrackParticlesAuxDyn.truthParticleLink/InDetTrackParticlesAuxDyn.truthParticleLink.m_persKey
# InDetTrackParticlesAuxDyn.truthParticleLink/InDetTrackParticlesAuxDyn.truthParticleLink.m_persIndex
# InDetTrackParticlesAuxDyn.numberOfPixelHits
# InDetTrackParticlesAuxDyn.numberOfPixelHoles
# InDetTrackParticlesAuxDyn.numberOfPixelSharedHits
# InDetTrackParticlesAuxDyn.numberOfPixelDeadSensors
# InDetTrackParticlesAuxDyn.numberOfSCTHits
# InDetTrackParticlesAuxDyn.numberOfSCTHoles
# InDetTrackParticlesAuxDyn.numberOfSCTSharedHits
# InDetTrackParticlesAuxDyn.numberOfSCTDeadSensors
# InDetTrackParticlesAuxDyn.qOverP
# InDetTrackParticlesAuxDyn.numberOfInnermostPixelLayerHits
# InDetTrackParticlesAuxDyn.TTVA_AMVFVertices
# InDetTrackParticlesAuxDyn.TTVA_AMVFWeights
# InDetTrackParticlesAuxDyn.chiSquared
# InDetTrackParticlesAuxDyn.numberDoF
# InDetTrackParticlesAuxDyn.d0
# InDetTrackParticlesAuxDyn.z0
# InDetTrackParticlesAuxDyn.theta
# InDetTrackParticlesAuxDyn.vz
# InDetTrackParticlesAuxDyn.numberOfTRTHits
# InDetTrackParticlesAuxDyn.numberOfTRTOutliers
# Kt4EMPFlowEventShapeAuxDyn.Density
# MET_Core_AnalysisMETAuxDyn.name
# MET_Core_AnalysisMETAuxDyn.mpx
# MET_Core_AnalysisMETAuxDyn.mpy
# MET_Core_AnalysisMETAuxDyn.sumet
# MET_Core_AnalysisMETAuxDyn.source
# MET_TruthAuxDyn.name
# MET_TruthAuxDyn.mpx
# MET_TruthAuxDyn.mpy
# MET_TruthAuxDyn.sumet
# MET_TruthAuxDyn.source
# MuonSpectrometerTrackParticlesAuxDyn.definingParametersCovMatrixDiag
# MuonSpectrometerTrackParticlesAuxDyn.definingParametersCovMatrixOffDiag
# MuonSpectrometerTrackParticlesAuxDyn.phi
# MuonSpectrometerTrackParticlesAuxDyn.truthParticleLink
# MuonSpectrometerTrackParticlesAuxDyn.truthParticleLink/MuonSpectrometerTrackParticlesAuxDyn.truthParticleLink.m_persKey
# MuonSpectrometerTrackParticlesAuxDyn.truthParticleLink/MuonSpectrometerTrackParticlesAuxDyn.truthParticleLink.m_persIndex
# MuonSpectrometerTrackParticlesAuxDyn.qOverP
# MuonSpectrometerTrackParticlesAuxDyn.d0
# MuonSpectrometerTrackParticlesAuxDyn.z0
# MuonSpectrometerTrackParticlesAuxDyn.theta
# MuonSpectrometerTrackParticlesAuxDyn.vz
# PrimaryVerticesAuxDyn.trackParticleLinks
# PrimaryVerticesAuxDyn.neutralParticleLinks
# PrimaryVerticesAuxDyn.x
# PrimaryVerticesAuxDyn.y
# PrimaryVerticesAuxDyn.z
# PrimaryVerticesAuxDyn.vertexType
# TauTracksAuxDyn.pt
# TauTracksAuxDyn.eta
# TauTracksAuxDyn.phi
# TauTracksAuxDyn.trackLinks
# TauTracksAuxDyn.flagSet
# TruthBosonAuxDyn.prodVtxLink
# TruthBosonAuxDyn.prodVtxLink/TruthBosonAuxDyn.prodVtxLink.m_persKey
# TruthBosonAuxDyn.prodVtxLink/TruthBosonAuxDyn.prodVtxLink.m_persIndex
# TruthBosonAuxDyn.decayVtxLink
# TruthBosonAuxDyn.decayVtxLink/TruthBosonAuxDyn.decayVtxLink.m_persKey
# TruthBosonAuxDyn.decayVtxLink/TruthBosonAuxDyn.decayVtxLink.m_persIndex
# TruthBosonAuxDyn.parentLinks
# TruthBosonAuxDyn.childLinks
# TruthBosonAuxDyn.m
# TruthBosonAuxDyn.px
# TruthBosonAuxDyn.py
# TruthBosonAuxDyn.pz
# TruthBosonAuxDyn.e
# TruthBosonAuxDyn.pdgId
# TruthBosonAuxDyn.classifierParticleOrigin
# TruthBosonAuxDyn.Classification
# TruthBosonAuxDyn.barcode
# TruthBosonAuxDyn.status
# TruthBosonAuxDyn.classifierParticleType
# TruthBosonAuxDyn.classifierParticleOutCome
# TruthBosonAuxDyn.polarizationPhi
# TruthBosonAuxDyn.polarizationTheta
# TruthBosonsWithDecayParticlesAuxDyn.prodVtxLink
# TruthBosonsWithDecayParticlesAuxDyn.prodVtxLink/TruthBosonsWithDecayParticlesAuxDyn.prodVtxLink.m_persKey
# TruthBosonsWithDecayParticlesAuxDyn.prodVtxLink/TruthBosonsWithDecayParticlesAuxDyn.prodVtxLink.m_persIndex
# TruthBosonsWithDecayParticlesAuxDyn.decayVtxLink
# TruthBosonsWithDecayParticlesAuxDyn.decayVtxLink/TruthBosonsWithDecayParticlesAuxDyn.decayVtxLink.m_persKey
# ...
# TruthTausAuxDyn.eta_vis
# TruthTausAuxDyn.phi_vis
# TruthTausAuxDyn.m_vis
# TruthTausAuxDyn.barcode
# TruthTausAuxDyn.status
# TruthTausAuxDyn.classifierParticleType
# TruthTausAuxDyn.classifierParticleOutCome
# TruthTausAuxDyn.originalTruthParticle
# TruthTausAuxDyn.originalTruthParticle/TruthTausAuxDyn.originalTruthParticle.m_persKey
# TruthTausAuxDyn.originalTruthParticle/TruthTausAuxDyn.originalTruthParticle.m_persIndex
# TruthTausAuxDyn.polarizationPhi
# TruthTausAuxDyn.polarizationTheta
# TruthTausAuxDyn.pt_vis_dressed
# TruthTausAuxDyn.eta_vis_dressed
# TruthTausAuxDyn.phi_vis_dressed
# TruthTausAuxDyn.m_vis_dressed
# TruthTausAuxDyn.nPhotons_dressed
# TruthTausAuxDyn.dressedPhoton
# TruthTausAuxDyn.numCharged
# TruthTausAuxDyn.numChargedPion
# TruthTausAuxDyn.numNeutral
# TruthTausAuxDyn.numNeutralPion
# TruthTausAuxDyn.IsHadronicTau
# TruthTausAuxDyn.pt_invis
# TruthTausAuxDyn.eta_invis
# TruthTausAuxDyn.phi_invis
# TruthTausAuxDyn.m_invis
# TruthTausAuxDyn.pt_vis_neutral
# TruthTausAuxDyn.eta_vis_neutral
# TruthTausAuxDyn.phi_vis_neutral
# TruthTausAuxDyn.m_vis_neutral
# TruthTausAuxDyn.DecayModeVector
# TruthTausAuxDyn.decay_vertex_x
# TruthTausAuxDyn.decay_vertex_y
# TruthTausAuxDyn.decay_vertex_z
# TruthTausAuxDyn.prod_vertex_x
# TruthTausAuxDyn.prod_vertex_y
# TruthTausAuxDyn.prod_vertex_z
# AnalysisTrigMatch_HLT_mu60_0eta105_msonlyAuxDyn.TrigMatchedObjects
# AnalysisElectronsAuxDyn.trackParticleLinks
# AnalysisElectronsAuxDyn.ambiguityLink
# AnalysisElectronsAuxDyn.ambiguityLink/AnalysisElectronsAuxDyn.ambiguityLink.m_persKey
# AnalysisElectronsAuxDyn.ambiguityLink/AnalysisElectronsAuxDyn.ambiguityLink.m_persIndex
# AnalysisElectronsAuxDyn.pt
# AnalysisElectronsAuxDyn.eta
# AnalysisElectronsAuxDyn.phi
# AnalysisElectronsAuxDyn.m
# AnalysisElectronsAuxDyn.charge
# AnalysisElectronsAuxDyn.topoetcone20
# AnalysisElectronsAuxDyn.f1
# AnalysisElectronsAuxDyn.truthType
# AnalysisElectronsAuxDyn.truthOrigin
# AnalysisElectronsAuxDyn.truthParticleLink
# AnalysisElectronsAuxDyn.truthParticleLink/AnalysisElectronsAuxDyn.truthParticleLink.m_persKey
# AnalysisElectronsAuxDyn.truthParticleLink/AnalysisElectronsAuxDyn.truthParticleLink.m_persIndex
# AnalysisElectronsAuxDyn.neflowisol20
# AnalysisElectronsAuxDyn.ptvarcone30_Nonprompt_All_MaxWeightTTVALooseCone_pt1000
# AnalysisElectronsAuxDyn.ptcone20_Nonprompt_All_MaxWeightTTVALooseCone_pt1000
# AnalysisElectronsAuxDyn.ptvarcone30_Nonprompt_All_MaxWeightTTVALooseCone_pt1000_CloseByCorr
# AnalysisElectronsAuxDyn.topoetcone20_CloseByCorr
# AnalysisElectronsAuxDyn.ptcone20_Nonprompt_All_MaxWeightTTVALooseCone_pt1000_CloseByCorr
# AnalysisElectronsAuxDyn.DFCommonElectronsLHLoose
# AnalysisElectronsAuxDyn.DFCommonElectronsLHLooseBLIsEMValue
# AnalysisElectronsAuxDyn.TruthLink
# AnalysisElectronsAuxDyn.TruthLink/AnalysisElectronsAuxDyn.TruthLink.m_persKey
# AnalysisElectronsAuxDyn.TruthLink/AnalysisElectronsAuxDyn.TruthLink.m_persIndex
# AnalysisElectronsAuxDyn.caloClusterLinks
# AnalysisElectronsAuxDyn.author
# AnalysisElectronsAuxDyn.OQ
# AnalysisElectronsAuxDyn.ambiguityType
# AnalysisElectronsAuxDyn.topoetcone20ptCorrection
# AnalysisElectronsAuxDyn.ptcone20_Nonprompt_All_MaxWeightTTVALooseCone_pt500
# AnalysisElectronsAuxDyn.ptvarcone30_Nonprompt_All_MaxWeightTTVALooseCone_pt500
# AnalysisElectronsAuxDyn.DFCommonElectronsLHVeryLoose
# AnalysisElectronsAuxDyn.DFCommonElectronsLHVeryLooseIsEMValue
# AnalysisElectronsAuxDyn.DFCommonElectronsLHLooseIsEMValue
# AnalysisElectronsAuxDyn.DFCommonElectronsLHLooseBL
# AnalysisElectronsAuxDyn.DFCommonElectronsLHMedium
# AnalysisElectronsAuxDyn.DFCommonElectronsLHMediumIsEMValue
# AnalysisElectronsAuxDyn.DFCommonElectronsLHTight
# AnalysisElectronsAuxDyn.DFCommonElectronsLHTightIsEMValue
# AnalysisElectronsAuxDyn.DFCommonElectronsECIDS
# AnalysisElectronsAuxDyn.DFCommonElectronsECIDSResult
# AnalysisElectronsAuxDyn.truthPdgId
# AnalysisElectronsAuxDyn.firstEgMotherTruthType
# AnalysisElectronsAuxDyn.firstEgMotherTruthOrigin
# AnalysisElectronsAuxDyn.firstEgMotherPdgId
# AnalysisElectronsAuxDyn.firstEgMotherTruthParticleLink
# AnalysisElectronsAuxDyn.firstEgMotherTruthParticleLink/AnalysisElectronsAuxDyn.firstEgMotherTruthParticleLink.m_persKey
# AnalysisElectronsAuxDyn.firstEgMotherTruthParticleLink/AnalysisElectronsAuxDyn.firstEgMotherTruthParticleLink.m_persIndex
# AnalysisTrigMatch_HLT_e10_lhvloose_L1EM7AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e10_lhvloose_nod0_L1EM7AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e12_lhvloose_L1EM10VHAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e12_lhvloose_nod0_L1EM10VHAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e15_lhvloose_L1EM13VHAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e15_lhvloose_nod0_L1EM7AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e17_lhvlooseAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e17_lhvloose_nod0AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e20_lhvlooseAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e20_lhvloose_nod0AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e24_lhvloose_nod0_L1EM18VHAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e26_lhvloose_nod0_L1EM20VHAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e28_lhvloose_nod0_L1EM20VHAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e5_lhvlooseAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e5_lhvloose_nod0AuxDyn.TrigMatchedObjects
# GSFTrackParticlesAuxDyn.definingParametersCovMatrixDiag
# GSFTrackParticlesAuxDyn.definingParametersCovMatrixOffDiag
# GSFTrackParticlesAuxDyn.phi
# GSFTrackParticlesAuxDyn.originalTrackParticle
# GSFTrackParticlesAuxDyn.originalTrackParticle/GSFTrackParticlesAuxDyn.originalTrackParticle.m_persKey
# GSFTrackParticlesAuxDyn.originalTrackParticle/GSFTrackParticlesAuxDyn.originalTrackParticle.m_persIndex
# GSFTrackParticlesAuxDyn.numberOfPixelHits
# GSFTrackParticlesAuxDyn.numberOfSCTHits
# GSFTrackParticlesAuxDyn.qOverP
# GSFTrackParticlesAuxDyn.numberOfInnermostPixelLayerHits
# GSFTrackParticlesAuxDyn.numberOfNextToInnermostPixelLayerHits
# GSFTrackParticlesAuxDyn.expectInnermostPixelLayerHit
# GSFTrackParticlesAuxDyn.expectNextToInnermostPixelLayerHit
# GSFTrackParticlesAuxDyn.chiSquared
# GSFTrackParticlesAuxDyn.d0
# GSFTrackParticlesAuxDyn.z0
# GSFTrackParticlesAuxDyn.theta
# GSFTrackParticlesAuxDyn.vz
# AnalysisTrigMatch_HLT_e17_lhmedium_iloose_tau25_medium1_tracktwoAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e17_lhmedium_nod0_iloose_tau25_medium1_tracktwoAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e17_lhmedium_nod0_ivarloose_tau25_medium1_tracktwoAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e17_lhmedium_nod0_ivarloose_tau25_medium1_tracktwo_L1DR-EM15TAU12I-J25AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e17_lhmedium_nod0_tau25_medium1_tracktwoAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e17_lhmedium_tau25_medium1_tracktwoAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e24_lhmedium_L1EM20VHAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e24_lhmedium_iloose_L1EM20VHAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e24_lhmedium_nod0_iloose_L1EM20VHAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e24_lhmedium_nod0_ivarloose_tau35_medium1_tracktwoAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e24_lhtight_nod0_ivarlooseAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e26_lhtight_cutd0dphideta_ivarlooseAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e26_lhtight_ivarlooseAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e26_lhtight_nod0AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e26_lhtight_nod0_ivarlooseAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e26_lhtight_smooth_ivarlooseAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e28_lhtight_nod0_L1EM22VHIAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e60_lhmediumAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e60_lhmedium_L1EM24VHIAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e60_lhmedium_nod0AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e60_lhvloose_nod0AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e60_mediumAuxDyn.TrigMatchedObjects
# GSFConversionVerticesAuxDyn.trackParticleLinks
# GSFConversionVerticesAuxDyn.neutralParticleLinks
# GSFConversionVerticesAuxDyn.px
# GSFConversionVerticesAuxDyn.py
# GSFConversionVerticesAuxDyn.pz
# GSFConversionVerticesAuxDyn.x
# GSFConversionVerticesAuxDyn.y
# GSFConversionVerticesAuxDyn.z
# GSFConversionVerticesAuxDyn.minRfirstHit
# GSFConversionVerticesAuxDyn.pt1
# GSFConversionVerticesAuxDyn.pt2
# AnalysisTrigMatch_HLT_e17_lhloose_mu14AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e17_lhloose_nod0_mu14AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu4_j55_bperf_split_dr05_dz02AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu6_j85_bperf_split_dr05_dz02AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e7_lhmedium_mu24AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e7_lhmedium_nod0_mu24AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_2e12_lhloose_L12EM10VHAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_2e12_lhvloose_L12EM10VHAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_2e12_lhvloose_nod0_L12EM10VHAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_2e15_lhvloose_L12EM13VHAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_2e15_lhvloose_nod0_L12EM13VHAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_2e17_lhvlooseAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_2e17_lhvloose_nod0AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e100_lhvloose_nod0AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e70_lhvloose_nod0AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e80_lhvloose_nod0AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu20_msonly_mu6noL1_msonly_nscan05AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu6_iloose_mu6_11invm24_noosAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e120_lhlooseAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e120_lhloose_nod0AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e120_lhvloose_nod0AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e140_lhloose_nod0AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e140_lhvloose_nod0AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e17_lhmedium_nod0_tau80_medium1_tracktwoAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e17_lhmedium_tau80_medium1_tracktwoAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu6_j110_bperf_split_dr05_dz02AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu6_j150_bperf_split_dr05_dz02AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu6_j175_bperf_split_dr05_dz02AuxDyn.TrigMatchedObjects
# FourLeptonVerticesAuxDyn.trackParticleLinks
# FourLeptonVerticesAuxDyn.x
# FourLeptonVerticesAuxDyn.y
# FourLeptonVerticesAuxDyn.z
# FourLeptonVerticesAuxDyn.vertexType
# FourLeptonVerticesAuxDyn.chiSquared
# FourLeptonVerticesAuxDyn.numberDoF
# AnalysisTrigMatch_HLT_mu11_nomucomb_mu6noL1_nscan03_L1MU11_2MU6_bTauAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu11_nomucomb_mu6noL1_nscan03_L1MU11_2MU6_bTau_delayedAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu18_2mu4noL1AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu18_mu8noL1AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu20_l2idonly_mu6noL1_nscan03AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e26_lhtight_nod0_e15_etcut_L1EM7_ZeeAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_2mu20_L12MU20_OVERLAYAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu13_mu13_idperf_ZmumuAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu10_bJpsi_TrklooseAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_2e12_lhloose_mu10AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_2e12_lhloose_nod0_mu10AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_2e12_lhloose_nodeta_L12EM10VHAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_2e12_lhloose_nodphires_L12EM10VHAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e200_etcutAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_g200_etcutAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_g120_looseAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_g140_looseAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e17_lhloose_2e9_lhlooseAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e17_lhloose_nod0_2e9_lhloose_nod0AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e17_lhmedium_nod0_iloose_2e9_lhmedium_nod0AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu20_ivarmedium_mu8noL1AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu20_mu8noL1AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu22_mu8noL1AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_2mu4_bJpsimumuAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_2mu6_bJpsimumuAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_2mu6_bJpsimumu_delayedAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu18_2mu4_JpsimumuL2AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu4_mu4_idperf_bJpsimumu_noidAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu6_mu4_bJpsimumuAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu6_mu4_bJpsimumu_delayedAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e17_lhloose_nod0_2e12_lhloose_nod0_L1EM15VH_3EM10VHAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e17_lhmedium_iloose_2e9_lhmediumAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e22_lhvloose_nod0_e12_lhvloose_nod0_e10_lhvloose_nod0_L1EM20VH_2EM10VH_3EM8VHAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e12_lhloose_2mu10AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e12_lhloose_nod0_2mu10AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e24_lhmedium_L1EM20VHI_mu8noL1AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e24_lhmedium_nod0_L1EM20VHI_mu8noL1AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e26_lhmedium_L1EM22VHI_mu8noL1AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e26_lhmedium_nod0_L1EM22VHI_mu8noL1AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu20_nomucomb_mu6noL1_nscan03AuxDyn.TrigMatchedObjects
# TruthForwardProtonsAuxDyn.prodVtxLink
# TruthForwardProtonsAuxDyn.prodVtxLink/TruthForwardProtonsAuxDyn.prodVtxLink.m_persKey
# TruthForwardProtonsAuxDyn.prodVtxLink/TruthForwardProtonsAuxDyn.prodVtxLink.m_persIndex
# TruthForwardProtonsAuxDyn.decayVtxLink
# TruthForwardProtonsAuxDyn.decayVtxLink/TruthForwardProtonsAuxDyn.decayVtxLink.m_persKey
# TruthForwardProtonsAuxDyn.decayVtxLink/TruthForwardProtonsAuxDyn.decayVtxLink.m_persIndex
# TruthForwardProtonsAuxDyn.m
# TruthForwardProtonsAuxDyn.px
# TruthForwardProtonsAuxDyn.py
# TruthForwardProtonsAuxDyn.pz
# TruthForwardProtonsAuxDyn.e
# TruthForwardProtonsAuxDyn.pdgId
# TruthForwardProtonsAuxDyn.classifierParticleOrigin
# TruthForwardProtonsAuxDyn.Classification
# TruthForwardProtonsAuxDyn.barcode
# TruthForwardProtonsAuxDyn.status
# TruthForwardProtonsAuxDyn.classifierParticleType
# TruthForwardProtonsAuxDyn.classifierParticleOutCome
# TruthForwardProtonsAuxDyn.polarizationPhi
# TruthForwardProtonsAuxDyn.polarizationTheta
# AnalysisTrigMatch_HLT_mu18_2mu0noL1_JpsimumuFSAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu20_2mu0noL1_JpsimumuFSAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu20_2mu4_JpsimumuL2AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu20_2mu4noL1AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu11_2mu4noL1_nscan03_L1MU11_2MU6AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu11_L1MU10_2mu4noL1_nscan03_L1MU10_2MU6AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu11_nomucomb_2mu4noL1_nscan03_L1MU11_2MU6AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_e300_etcutAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_g300_etcutAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_2mu4_bUpsimumuAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_2mu6_bUpsimumuAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_2mu6_bUpsimumu_delayedAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu6_mu4_bUpsimumuAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu6_mu4_bUpsimumu_delayedAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_2mu6_10invm30_pt2_z10AuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_g35_loose_g25_looseAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_2g20_tightAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_2g22_tightAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu20_msonly_mu15noL1_msonly_nscan05_noCombAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu20_msonly_mu10noL1_msonly_nscan05_noCombAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_2g20_loose_g15_looseAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_3g15_looseAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_3g20_looseAuxDyn.TrigMatchedObjects
# AnalysisTrigMatch_HLT_mu11_nomucomb_2mu4noL1_nscan03_L1MU11_2MU6_bTauAuxDyn.TrigMatchedObjects

# %% [markdown]
# ### Load branches into awkward and numpy arrays
#
# We can get a branch of a TTree by using `[branch_name]` and calling `.array()`.

# %%
el_pt = tree["AnalysisElectronsAuxDyn.pt"].array()

# %% [markdown]
# These vector branches are represented using awkward arrays. In this case, we are getting the transverse momentum ($p_T$) of all the electrons in each event. For each event we have a variable lenght of electrons, in a total of 120,000 events.

# %%
el_pt
# Out:
# <Array [[], [], [], [], ..., [], [1.83e+04], []] type='160000 * var * float32'>

# %% [markdown]
# > Note: `120000 * var * float32` means: 120000 events, made by arrays of *var*iable lenght, comprised by floats (that represent the $p_T$ of the electrons in this case).

# %% [markdown]
# For plotting the $p_T$ distribution, we flatten the array to get the $p_T$ of all the electrons in a 1D array:

# %%
el_pt_np = ak.flatten(el_pt).to_numpy()
print(f'Total number of electrons in 120,000 events: {len(el_pt_np):,}')
el_pt_np
# Out:
# Total number of electrons in 120,000 events: 103,743
# array([49111.31  ,  8444.114 , 66848.984 , ...,  8894.669 ,  6639.8667,
#        18323.871 ], shape=(103743,), dtype=float32)

# %%
plt.hist(el_pt_np, bins=100)
plt.title('$p_T$ distribution of all $e$')
plt.xlabel('$p_T$')
plt.ylabel('Number of electrons')
plt.show()

# %% [markdown]
# ## Simple analysis
#
# To demonstrate the use of a PHYSLITE, we will work trough a very basic $t\bar{t}$ analysis. Inspired by the [Analysis Grand Challenge (AGC)](https://agc.readthedocs.io/en/latest/), the goal is to reconstruct the hadronically decaying top quark from semi-leptonic $t\bar{t}$ events. This means identifying the three jets that originated from the hadronic decay of one top quark and combining their information to estimate the quark's original properties.
#
# ![](img/ttbar.png)

# %% [markdown]
# ### Collect branches into records
# Doing the analysis using the arrays showed before would be inefficient. We are going to use the `.zip()` method from the `awkward` library. This let us can zip multiple arrays in a single structure.
#
# For the analysis we need some information from our PHYSLITE file. We are going to get $p_T$, the pseudorapidity ($\eta$), and the azimuthal angle ($\phi$). for electrons, muons, and jets. For jets, we are also getting their mass.

# %%
electrons = ak.zip(
    {
        "pt": tree["AnalysisElectronsAuxDyn.pt"].array(),
        "eta": tree["AnalysisElectronsAuxDyn.eta"].array(),
        "phi": tree["AnalysisElectronsAuxDyn.phi"].array(),
    }
)

muons = ak.zip(
     {
        "pt": tree["AnalysisMuonsAuxDyn.pt"].array(),
        "eta": tree["AnalysisMuonsAuxDyn.eta"].array(),
        "phi": tree["AnalysisMuonsAuxDyn.phi"].array(),
    }
)

jets = ak.zip(
     {
        "pt": tree["AnalysisJetsAuxDyn.pt"].array(),
        "eta": tree["AnalysisJetsAuxDyn.eta"].array(),
        "phi": tree["AnalysisJetsAuxDyn.phi"].array(),
        "mass": tree["AnalysisJetsAuxDyn.m"].array(),
    }
)

# %% [markdown]
# We have structured our information into record arrays, where each record represents the properties of electrons/muons/jets detected in various events.
#
# If we check the estructure of the electrons, for each electron within each event, we record three properties:
#
# - The outermost structure is a list, where each element corresponds to a single event. This means each item in this list represents all the electrons detected for a particular event.
# - Inside each of these event lists, we have zero or more records. Each record is a dictionary that details the properties of a single electron. Specifically, the records contain:
#     - pt: The transverse momentum of the electron, measured in electron volts (eV), indicating the component of the momentum perpendicular to the beam direction.
#     - eta: The pseudorapidity, which is a spatial coordinate describing the angle of the particle relative to the beam axis. It helps in understanding the direction of the particle's movement.
#     - phi: The azimuthal angle in the transverse plane, providing the direction of the particle around the beam axis.
#
# For example, an empty list [] indicates an event where no electrons were detected. A non-empty list, such as [{pt: 7.65e+03, eta: -1.33, phi: -0.0518}, {pt: 3.94e+03, eta: ..., ...}], signifies an event where two electrons were detected, each with its respective $p_T$, $\eta$, and $\phi$ values detailed.

# %%
electrons
# Out:
# <Array [[], [], ..., [{pt: 1.83e+04, ...}], []] type='160000 * var * {pt: f...'>

# %% [markdown]
# The dataset contains a total of 90,000 variable-length records, each structured as follows:
#
# ```
# type: 90000 * var * {
#     pt: float32,
#     eta: float32,
#     phi: float32
# }
# ```
# This indicates that we have a dynamic array of up to 90,000 events, and for each event, there can be a variable number of electrons detected, with each electron's properties ($p_T$, $\eta$, $\phi$) stored as 32-bit floating-point numbers.
#
# This organization allows for efficient storage and processing of the physical properties of electrons across a large number of particle collision events

# %% [markdown]
# We can access the fields conveniently via attribute or dictionary access:

# %%
electrons.pt
# Out:
# <Array [[], [], [], [], ..., [], [1.83e+04], []] type='160000 * var * float32'>

# %%
electrons["pt"]
# Out:
# <Array [[], [], [], [], ..., [], [1.83e+04], []] type='160000 * var * float32'>

# %% [markdown]
# For the jets we'll also need BTagging information. Technically this would be provided by ElementLinks (cross references), but here in PHYSLITE we have exactly one btagging value for each jet in the `BTagging_AntiKt4EMPFlowAuxDyn.DL1dv01_pb` branch.

# %%
btag_prob = tree["BTagging_AntiKt4EMPFlowAuxDyn.DL1dv01_pb"].array()

# %%
ak.all(ak.num(btag_prob) == ak.num(jets))
# Out:
# np.True_

# %% [markdown]
# Since we have a value for each jet, we can just attach this as an additional field to our jets as we would do in a dictionary.

# %%
jets["btag_prob"] = btag_prob
jets
# Out:
# <Array [[{pt: 4.8e+04, ...}, ..., {...}], ...] type='160000 * var * {pt: fl...'>

# %% [markdown]
# To facilitate convenient event selections, we organize all detected particle types—electrons, muons, and jets—into a single record array named events. This structure allows us to access all relevant data for each event in a unified manner.
#
# Each entry in the events array corresponds to a specific collision event and contains the records for electrons, muons, and jets. It's important to note that we use `depth_limit=1` during this organization process. This parameter ensures that while the first dimension (representing individual events) is uniform in length across the dataset, the second dimension (index 1) can accommodate lists of arbitrary lengths to account for the varying number of particles detected per event.
#
# The data is organized by electrons, muons, jets. Each of these keys within an event's record holds the list of records, defined above, for the respective particle type. If a particular type of particle was not detected in an event, its list will be empty ([]). For instance, an event with no electrons but with muons and jets will have an empty list for electrons and populated lists for muons and jets.
#
# An example entry might look like this:
#
# ```
# {
#   Electrons: [{pt: ..., eta: ..., phi: ...}, ...],
#   Muons: [{pt: ..., eta: ..., phi: ...}, ...],
#   Jets: [{pt: ..., eta: ..., phi: ..., mass: ..., btag_prob: ...}, ...]
# }
# ```

# %%
events = ak.zip({"Electrons": electrons, "Muons": muons, "Jets": jets}, depth_limit=1)
events
# Out:
# <Array [{Electrons: [], Muons: ..., ...}, ...] type='160000 * {Electrons: v...'>

# %% [markdown]
# This organizational scheme, encapsulated as:
# ```
# type: 90000 * {
#     Electrons: var * {
#         pt: float32,
#         eta: float32,
#         phi: float32
#     },
#     Muons: var * {
#         pt: float32,
#         eta: float32,
#         phi: float32
#     },
#     Jets: var * {
#         pt: float32,
#         eta: float32,
#         phi: float32,
#         mass: float32,
#         btag_prob: float32
#     }
# }
# ```
# describes a dataset of 90,000 events, where each event can contain a variable number of Electrons, Muons, and Jets. Each particle's properties are stored as 32-bit floating-point numbers.

# %% [markdown]
# ### Event and object selection
# - **At least 4 Jets Required:** In a $t\bar{t}$ event, one top quark decays hadronically (into three jets) while the other decays leptonically (into a lepton and a b-jet alongside a neutrino). The requirement for at least four jets reflects the need to capture both decay channels. Specifically, one jet is expected from the leptonic decay (the b-jet) and three from the hadronic decay.
#
# - **Exactly One Electron or Muon:** This particle should have reasonably high $p_T$ and be centrally located within the detector (indicating its $\eta$ is within a central range). The presence of exactly one high-$p_T$, centrally-located electron or muon ensures we're observing a semi-leptonic $t\bar{t}$ decay, where one top quark decays into a lepton (electron or muon), a neutrino, and a b-jet. This criterion helps filter events that closely match the expected signature of a $t\bar{t}$ event.
#
# - **B-tagging with 85% Working Point:** B-tagging is a technique used to identify jets originating from b-quarks. The "85% working point" refers to a specific threshold in the b-tagging algorithm that offers an 85% probability of correctly identifying b-jets. Choosing this working point balances the need for high b-jet identification efficiency with the control of mistakenly tagging light-quark or gluon jets as b-jets (misidentification rate).
#
# - **At Least 2 B-jets:** Since both top quarks in a $t\bar{t}$ event decay into a b-quark (one directly in the hadronic decay and one as part of the leptonic decay chain), identifying at least two b-jets in an event is crucial. This ensures that the selection process captures the events that likely represent the decay products of a pair of top quarks.
#
# By adhering to these selection criteria, the analysis aims to filter the dataset for events that are most representative of semi-leptonic $t\bar{t}$ decays, facilitating a focused and efficient study of the hadronically decaying top quark.

# %% [markdown]
# #### Basic object selections
#
# The object selection is done using boolean masks—a way to select only those elements that meet our criteria. Selections work like in `numpy`, by passing a boolean mask like `[mask]`. A boolean mask is essentially an array where each element is either True (if the condition is met) or False (if the condition is not met). When applied to the dataset, it filters out only the True elements.
#
# We define a condition (e.g., electrons.pt > 30 * GeV) to create a mask. This condition checks if the transverse momentum of each electron is greater than 30 GeV (where GeV = 1000. is a unit conversion factor). The result is a boolean mask array indicating with True or False whether each electron in each event meets the condition.

# %%
GeV = 1000.
mask = electrons.pt > 30 * GeV
mask
# Out:
# <Array [[], [], [], [], ..., [], [], [False], []] type='160000 * var * bool'>

# %% [markdown]
# Applying the mask to the electrons array (electrons[mask]) filters out only those electrons that meet the condition. If none meet the condition, the result for that event is an empty list. This process generalizes to lists, allowing us to work with vector branches.

# %%
electrons[mask]
# Out:
# <Array [[], [], [], [], ..., [], [], [], []] type='160000 * var * {pt: floa...'>

# %% [markdown]
# We define functions (selected_electrons, selected_muons, selected_jets) to encapsulate the selection logic. These functions return only the particles from each event that meet both conditions:
# - Their $p_T$ is greater than 30 GeV.
# - Their $\eta$ is within a certain range ($|\eta| < 2.47$), ensuring they are centrally located within the detector.

# %%
def selected_electrons(el):
    return el[(el.pt > 30 * GeV) & (abs(el.eta) < 2.47)]

def selected_muons(mu):
    return mu[(mu.pt > 30 * GeV) & (abs(mu.eta) < 2.47)]

def selected_jets(j):
    return j[(j.pt > 30 * GeV) & (abs(j.eta) < 2.47)]

# %% [markdown]
# We apply these selections to all our objects in the `events` record:

# %%
events["Electrons"] = selected_electrons(electrons)
events["Muons"] = selected_muons(muons)
events["Jets"] = selected_jets(jets)

# %%
print(f'Number of electrons before selection: {ak.count(electrons.pt):,}')
print(f'Number of electrons after selection: {ak.count(events.Electrons.pt):,}')
# Out:
# Number of electrons before selection: 103,743
# Number of electrons after selection: 42,001

# %% [markdown]
# #### Lorentz vectors
# The vector package in Python provides tools to treat collections of particle properties as vectors. This is particularly useful for performing geometric and kinematic calculations, such as transformations and invariant mass calculations.
#
# We start by converting the properties of particles (Electrons, Muons, Jets) into Lorentz vectors. This involves associating their physical properties (e.g., transverse momentum, pseudorapidity, azimuthal angle) with the components of a vector. The function `vector.awk()` is applied to the properties of Electrons, Muons, and Jets. This operation effectively converts the data structure holding the particles' properties into one that supports vector operations.

# %%
events["Electrons"] = vector.awk(events.Electrons)
events["Muons"] = vector.awk(events.Muons)
events["Jets"] = vector.awk(events.Jets)

# %%
events.Electrons
# Out:
# <MomentumArray3D [[], [], [], [], ..., [], [], [], []] type='160000 * var *...'>

# %% [markdown]
# After conversion, you can access specific vector components directly. For instance, accessing the $p_x$ component (the x-component of the momentum vector) of each electron becomes straightforward.

# %%
events.Electrons.px
# Out:
# <Array [[], [], [], [], ..., [], [], [], []] type='160000 * var * float32'>

# %% [markdown]
# #### Overlap removal
#
# Overlap removal is an essential step in particle physics analyses to ensure that the same physical object is not misidentified as multiple types of particles. When particles like electrons and jets are detected close to each other in the detector, it can create ambiguity about their identities. This section explains how to identify and remove such overlaps, focusing on the overlap between electrons and jets.
#
# ##### Understanding Overlap Removal
# 1. **Identifying Overlaps with Cartesian Product**:
#
#     The process begins by considering all possible pairs (combinations) of electrons and jets within each event. This is known as creating a Cartesian product.
#     `ak.cartesian([events.Jets, events.Electrons], nested=True)` generates all combinations of jets and electrons. The `nested=True` parameter adds an additional dimension to the array, which represents each possible pair of jet and electron.
#
#     The result of `ak.cartesian` is then split into two arrays (`jj` for jets and `ee` for electrons) using `ak.unzip`. This effectively separates the pairs into corresponding jets and electrons arrays but keeps them linked by their indices within these arrays.
#
# 2. **Calculating the Separation with $\Delta R$**:
#
#     The next step involves calculating the separation between each jet-electron pair. This separation is quantified using a metric called $\Delta R$, which combines differences in their azimuthal angle ($\phi$) and pseudorapidity ($\eta$) into a single distance measure. `jj.deltaR(ee)` calculates the $\Delta R$ between each jet and electron in the pairs generated. Plotting the histogram of $\Delta R$ values for all jet-electron pairs gives insight into how closely jets and electrons are located to each other in the detector.

# %%
jj, ee = ak.unzip(ak.cartesian([events.Jets, events.Electrons], nested=True))
plt.hist(ak.flatten(jj.deltaR(ee), axis=None).to_numpy(), bins=100)
plt.xlabel(r"$\Delta R(j, e)$ (for all jet–electron pairs)")
plt.ylabel("Count of Jet-Electron Pairs")
plt.title(r"Distribution of $\Delta R$ Between Jets and Electrons")
plt.show()

# %% [markdown]
# 3. **Defining and Applying Overlap Removal Criteria**:
#
#     A common criterion for overlap removal is to exclude jets that are within a certain $\Delta R$ distance from an electron, typically $\Delta R < 0.4$.
#     The function `no_overlap(obj1, obj2, deltaR=0.4)` checks for each jet if there is any electron within a $\Delta R$ of 0.4. It uses `ak.all(obj1.deltaR(obj2) > deltaR, axis=-1)` to return a boolean mask where True indicates a jet does not overlap any electron by this criterion. This mask can then be applied to the jets array to filter out those jets that are too close to electrons, ensuring they are not double-counted as both jets and electrons.

# %%
def no_overlap(obj1, obj2, deltaR=0.4):
    obj1, obj2 = ak.unzip(ak.cartesian([obj1, obj2], nested=True))
    return ak.all(obj1.deltaR(obj2) > deltaR, axis=-1)

# %% [markdown]
# After defining the no_overlap function, it's used to create a mask for jets that do not overlap with electrons:

# %%
no_overlap(events.Jets, events.Electrons) # mask for each jet if it has no overlap with any electron
# Out:
# <Array [[True], ..., [True, True, ..., True, True]] type='160000 * var * bool'>

# %% [markdown]
# This mask is then applied to the jets in the events:

# %%
events["Jets"] = events.Jets[no_overlap(events.Jets, events.Electrons)]

# %% [markdown]
# This step updates the events dataset to only include jets that have passed the overlap removal criteria, ensuring a cleaner separation of particle types.

# %% [markdown]
# #### Apply event selection
# After cleaning the dataset through overlap removal, applying event selection criteria helps isolate the events that are most relevant to the specific analysis goal. In this case, the criteria are tailored for $t\bar{t}$ analysis, and were explained above:
# - At least 4 Jets
# - Exactly One Lepton (Electron or Muon)
# - At Least Two B-tagged Jets with Prob > 0.85

# %%
events["Jets", "is_bjet"] = events.Jets.btag_prob > 0.85

events = events[
    (ak.num(events.Jets) >= 4) # at least 4 jets
    & ((ak.num(events.Electrons) + ak.num(events.Muons)) == 1) # exactly one lepton
    & (ak.num(events.Jets[events.Jets.is_bjet]) >= 2) # at least two btagged jets with prob > 0.85
]

# %%
print(f'Initially we had 120,000 events. After the event selection we have {len(events):,} events')
# Out:
# Initially we had 120,000 events. After the event selection we have 7,836 events

# %% [markdown]
# ### Top quark reconstruction
#
# As we progress through our $t\bar{t}$ analysis, the next critical step involves reconstructing the top quark from the decay products observed in our events. This section outlines a streamlined approach to piecing together the decay signature of the top quark from jet combinations, focusing on key criteria that align with the characteristics of top quark decays.
#
# #### Procedure for Top Quark Reconstruction:
# 1. **Combining Jets**:
#     We start by generating all possible combinations of three jets within each event. This step is foundational, considering the typical hadronic decay of a top quark results in three jets.
#
# 2. **Incorporating B-jets**:
#     To refine our combinations, we require that at least one jet in each combination is b-tagged (`is_bjet`). This reflects the decay pathway of the top quark, where one jet is expected to originate from a b quark.
#
# 3. **Identifying the Best Candidate**:
#     Among these combinations, we then identify the one with the highest total $p_T$. This criterion helps select the combination most likely to represent the decay products of a top quark, based on the assumption that the decay of a massive particle like the top quark would produce high-momentum jets.

# %% [markdown]
# ### Implementation Through the mjjj Function:
# - **Creating Combinations**: Utilizes `ak.combinations(jets, 3)` to form every 3-jet group.
# - **Unpacking Jets**: Through `ak.unzip(candidates)`, the individual jets in each combination are extracted.
# - **Filtering for B-jets**: Ensures combinations include at least one b-jet by evaluating `(j1.is_bjet + j2.is_bjet + j3.is_bjet) > 0`.
# - **4-Momentum Calculation**: Computes the total 4-momentum for each jet trio, `candidates["p4"] = j1 + j2 + j3`.
# - **Selection of Top Candidate**: Chooses the jet combination with the highest pt as the top quark candidate, extracting its mass for the reconstruction.

# %%
def mjjj(jets):
    candidates = ak.combinations(jets, 3)
    j1, j2, j3 = ak.unzip(candidates)
    has_b = (j1.is_bjet + j2.is_bjet + j3.is_bjet) > 0
    candidates["p4"] = j1 + j2 + j3
    candidates = candidates[has_b]
    candidates = candidates[ak.argmax(candidates.p4.pt, axis=1, keepdims=True)]
    return candidates.p4.mass

# %% [markdown]
# Visualizing these masses through a histogram provides insights into the effectiveness of the reconstruction method and the characteristics of the top quark decays within our dataset. The most prominent feature to look for is a peak in the distribution that corresponds to the known mass of the top quark. The mass of the top quark is approximately 172.76 GeV/c². Therefore, a peak around this value indicates successful reconstruction of top quarks from the decay products.

# %%
plt.hist(ak.flatten(mjjj(events.Jets) / GeV, axis=None), bins=100)
plt.xlabel("Reconstructed Top Quark Mass (GeV)")
plt.ylabel("Number of Events")
plt.title("Distribution of Reconstructed Top Quark Mass")
plt.axvline(172.76, color='r', linestyle='dashed', linewidth=2, label='Expected Top Quark Mass')
plt.legend()
plt.show()

# %% [markdown]
# ### Run on larger number of files
#
# When scaling up data analysis to handle larger datasets, especially in high-energy physics where datasets can be enormous, managing memory usage becomes crucial to prevent running out of memory (OOM) errors. Here's a clearer explanation of the strategies mentioned for handling large-scale data processing efficiently:

# %% [markdown]
# #### Chunking the Processing
# This approach involves dividing the dataset into smaller, manageable pieces or "chunks" and processing each chunk sequentially. After processing a chunk, the results can be aggregated (e.g., accumulating in a histogram or ntuple), and the memory used by the chunk can be released before moving on to the next chunk. This method helps in managing memory usage effectively by ensuring that only a portion of the data is held in memory at any given time.
#
# - Advantages: Simple to implement and can significantly reduce memory usage.
# - Use Case: Particularly useful when operations on individual chunks are independent and can be aggregated easily.

# %% [markdown]
# #### Distributed Processing
# Distributed processing involves spreading the data and computations across multiple machines or processors. This not only helps in managing memory by leveraging the collective memory of multiple systems but also can speed up the processing by executing tasks in parallel. We won't discuss distributed processing in this tutorial, but there are nice possibilities to do this while still staying interactive by using [`dask`](https://www.dask.org/)

# %% [markdown]
# #### Processing Data in Chunks with Awkward Array
# For the specific case of processing large datasets of particle physics events, where the analysis might discard a significant number of events and only a subset of data columns are retained, processing data in chunks becomes highly efficient. Here's how you can do it:
#
# - **Process Each File Separately**: Instead of loading the entire dataset into memory, process each file one at a time. This limits the amount of data in memory to what's contained in a single file.
# - **Use `ak.to_packed` for Memory Efficiency**: After applying event selection and filtering out unnecessary data, the ak.to_packed function can be used to further reduce memory usage. This function optimizes the memory layout of the Awkward Array by eliminating unused spaces (from masks and indices) and ensuring that only the memory needed for the retained data is used.

# %%
memory_usage_kiB = ak.to_packed(events).nbytes / 1024
print(f"Memory usage: {memory_usage_kiB:.5} kiB")
# Out:
# Memory usage: 1028.0 kiB

# %% [markdown]
# This calculation gives you an estimate of the memory usage after compaction.

# %% [markdown]
# #### Organize code into functions
# First, we structure everything a bit more nicely into functions

# %% [markdown]
# ##### Defining a Schema
# The schema dictionary outlines the data structure expected from the input files. It maps each particle type (Electrons, Muons, Jets, and BTagging information) to the relevant attributes that will be read and processed. This schema is crucial for dynamically handling different data fields across various particle types.

# %%
schema = {
    "Electrons": [
        "pt", "eta", "phi",
    ],
    "Muons": [
        "pt", "eta", "phi",
    ],
    "Jets": [
        "pt", "eta", "phi", "m"
    ],
    "BTagging_AntiKt4EMPFlow": [
        "DL1dv01_pb",
    ]
}

# %% [markdown]
# ##### `read_events` Function
# Reads data from a file according to the specified schema, organizing the data into a structured format suitable for analysis.
#
# **Process:**
# - Opens a file using uproot and iterates over the schema to read specified fields for each particle type.
# - Uses `ak.zip` to combine the fields into structured arrays, preserving the relationship between different attributes of each particle type.
# - Returns a structured awkward array (`ak.zip(events, depth_limit=1)`) that encapsulates the event data, allowing for efficient, high-level operations on the dataset.

# %%
def read_events(filename, schema):
    with uproot.open({filename: "CollectionTree"}) as tree:
        events = {}
        for objname, fields in schema.items():
            base = objname
            if objname in ["Electrons", "Muons", "Jets"]:
                base = "Analysis" + objname
                ak_zip = vector.zip
            else:
                ak_zip = ak.zip
            arrays = tree.arrays(
                fields,
                aliases={field: f"{base}AuxDyn.{field}" for field in fields},
            )
            arrays = ak_zip(dict(zip(arrays.fields, ak.unzip(arrays))))
            events[objname] = arrays
        return ak.zip(events, depth_limit=1)

# %%
events = read_events(local_filename, schema)
events
# Out:
# <Array [{Electrons: [], Muons: ..., ...}, ...] type='160000 * {Electrons: v...'>

# %% [markdown]
# ##### `processed` Function
# Applies a series of processing steps to the events data to prepare it for analysis. This includes applying selection criteria and organizing data for efficient memory usage.
#
# **Process:**
# - Makes a shallow copy of the events to avoid mutating the original data.
# - Adds a `btag_prob` field to Jets based on BTagging information.
# - Applies selection functions (`selected_electrons`, `selected_muons`, `selected_jets`) to filter particles based on specific criteria (e.g., transverse momentum and pseudorapidity).
# - Removes overlapping jets with selected electrons to avoid double counting.
# - Flags jets as b-tagged jets (`is_bjet`) based on their b-tagging probability.
# - Applies event selection criteria to filter the events further, retaining those with at least four jets, exactly one lepton (electron or muon), and at least two b-tagged jets.
# - Compacts the data using ak.`to_packed` to reduce memory usage, discarding unnecessary indices and masks.
#
# It returns a processed and compacted dataset, ready for further analysis, with significantly reduced memory footprint.

# %%
def processed(events):
    events = copy.copy(events) # shallow copy
    events["Jets", "btag_prob"] = events.BTagging_AntiKt4EMPFlow.DL1dv01_pb
    events["Electrons"] = selected_electrons(events.Electrons)
    events["Muons"] = selected_muons(events.Muons)
    events["Jets"] = selected_jets(events.Jets)
    events["Jets"] = events.Jets[no_overlap(events.Jets, events.Electrons)]
    events["Jets", "is_bjet"] = events.Jets.btag_prob > 0.85
    events = events[
        (ak.num(events.Jets) >= 4) # at least 4 jets
        & ((ak.num(events.Electrons) + ak.num(events.Muons)) == 1) # exactly one lepton
        & (ak.num(events.Jets[events.Jets.is_bjet]) >= 2) # at least two btagged jets with prob > 0.85
    ]
    return ak.to_packed(events)

# %%
processed(events)
# Out:
# <Array [{...}, {...}, {...}, ..., {...}, {...}] type='7836 * {BTagging_Anti...'>

# %% [markdown]
# ### Pause a second and talk about performance
# We're taking a moment to discuss performance, specifically focusing on how time is allocated during different stages of data handling in a particle physics analysis workflow. By examining the time spent reading data into memory and processing it, we gain insights into potential bottlenecks and areas for optimization.

# %% [markdown]
# #### Time for reading arrays into memory
# It takes approximately 3.29 seconds to read arrays into memory. This measurement gives us a baseline for the time complexity associated with loading data from a file using the specified schema.
#
# For this specific example, which involves a relatively small file and a limited number of data branches (fields), a significant portion of the time is not spent on transferring large volumes of data into memory. Instead, it is mostly consumed by metadata operations, such as fetching the TTree object and accessing branch information. This overhead is intrinsic to the file format and the way data is stored and accessed.

# %%
# %timeit read_events(local_filename, schema)
# Out:
# 2.28 s ± 106 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### Time Spent Opening the File
# By isolating the action of merely opening the file and accessing the TTree object (only_open()), we find it takes about 1 second. This step does not involve reading any data into memory; it merely sets up access to the data.
#
# This result highlights that a significant fraction of the total read time is dedicated to overhead associated with file and data structure access in ROOT files. The implication is that improvements in how metadata is handled could lead to better performance.

# %%
def only_open():
    with uproot.open({local_filename: "CollectionTree"}) as tree:
        return tree

# %%
# %timeit only_open()
# Out:
# 855 ms ± 57.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# #### Time Spent on Processing
#
# The processing step, quantified by `%timeit processed(events)`, is notably faster. This difference emphasizes that once the data is in memory, computations and manipulations of the data (such as applying selection criteria and organizing data structures) are highly efficient.

# %%
# %timeit processed(events)
# Out:
# 194 ms ± 61.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# The comparison suggests that for small files or when accessing a limited number of branches, the overhead of dealing with metadata can dominate the time spent. This is an important consideration for performance optimization, particularly in workflows that involve many small files or require frequent access to different data branches.

# %% [markdown]
# ## Transforming PHYSLITE into N-Tuple
# The [N-tuple](https://opendata.atlas.cern/docs/documentation/data_format/ntuple) structure is widely used for physics analyses. One way to use the PHYSLITE files is by transforming it into a N-tuple. For more information on the topic, you can check the [ATLAS Analysis Software Tutorial](https://atlassoftwaredocs.web.cern.ch/analysis-software/ASWTutorial/), particularly [Writing NTuples and Trees using the Text Configuration](https://atlassoftwaredocs.web.cern.ch/analysis-software/AnalysisSWTutorial/cpalg_ntuple/).
